# %%
import os
import pandas as pd
import numpy as np
import editdistance
import time 

from PIL import Image
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn.functional as F

import timm  
from sklearn.model_selection import train_test_split

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Base project path
BASE_DIR = "/projects/qb36/lontar_project"
DATA_DIR = os.path.join(BASE_DIR, "data")

# Define file paths
ground_truth_path = os.path.join(DATA_DIR, 'balinese_transliteration_train.txt')
images_dir = os.path.join(DATA_DIR, 'balinese_word_train')

# %%
# base_dir = os.getcwd()

# # Same paths as your original code
# ground_truth_path = os.path.join(base_dir, 'balinese_transliteration_train.txt') 
# images_dir        = os.path.join(base_dir, 'balinese_word_train')


filenames = []
labels    = []

with open(ground_truth_path, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        if line:  # Ensure the line is not empty
            parts = line.split(';')
            if len(parts) == 2:
                filename, label = parts
                label = label.lower()
                filenames.append(filename)
                labels.append(label)
            else:
                print(f"Skipping malformed line: {line}")

data = pd.DataFrame({
    'filename': filenames,
    'label': labels
})

label_counts = data['label'].value_counts()

all_text = ''.join(data['label'])
unique_chars = sorted(list(set(all_text)))

# Create character->index starting from 1
char_to_idx = {char: idx + 1 for idx, char in enumerate(unique_chars)}
# Add special tokens
char_to_idx['<PAD>'] = 0
char_to_idx['<UNK>'] = len(char_to_idx)
char_to_idx['<SOS>'] = len(char_to_idx)
char_to_idx['<EOS>'] = len(char_to_idx)

# Reverse mapping
idx_to_char = {v: k for k, v in char_to_idx.items()}

vocab_size = len(char_to_idx)
print(f"Vocabulary size: {vocab_size}")

def encode_label(label, char_to_idx, max_length):
    """
    Converts a label (string) into a list of indices with <SOS>, <EOS>, padding, etc.
    """
    encoded = (
        [char_to_idx['<SOS>']] +
        [char_to_idx.get(ch, char_to_idx['<UNK>']) for ch in label] +
        [char_to_idx['<EOS>']]
    )
    # Pad if needed
    if len(encoded) < max_length:
        encoded += [char_to_idx['<PAD>']] * (max_length - len(encoded))
    else:
        encoded = encoded[:max_length]
    return encoded

max_label_length = max(len(label) for label in data['label']) + 2  # +2 for <SOS> and <EOS>
data['encoded_label'] = data['label'].apply(lambda x: encode_label(x, char_to_idx, max_label_length))
data['label_length']  = data['label'].apply(len)

rare_labels = label_counts[label_counts < 3].index  # NEW: words that appear <3 times

def custom_split(df, rare_label_list, test_size=0.1, random_state=42):
    # Separate rare words from frequent ones
    rare_df     = df[df['label'].isin(rare_label_list)]
    non_rare_df = df[~df['label'].isin(rare_label_list)]

    #  train/val split for non-rare
    train_nr, val_nr = train_test_split(non_rare_df, test_size=test_size, 
                                        random_state=random_state)

    # Combine rare samples entirely into training
    train_df = pd.concat([train_nr, rare_df], ignore_index=True)
    # Shuffle after combining
    train_df = train_df.sample(frac=1, random_state=random_state).reset_index(drop=True)

    val_df = val_nr.reset_index(drop=True)
    return train_df, val_df

# Call custom_split instead of direct train_test_split
train_data, val_data = custom_split(data, rare_labels, test_size=0.1, random_state=42) 

print(f"Training size: {len(train_data)}; Validation size: {len(val_data)}")
# Out:
# Vocabulary size: 39
# Training size: 13972; Validation size: 1050

# %%
class BalineseDataset(Dataset):
    def __init__(self, df, images_dir, transform=None):
        self.data       = df.reset_index(drop=True)
        self.images_dir = images_dir
        self.transform  = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name     = self.data.loc[idx, 'filename']
        label        = self.data.loc[idx, 'encoded_label']
        label_length = self.data.loc[idx, 'label_length']

        img_path = os.path.join(self.images_dir, img_name)
        image    = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = torch.tensor(label, dtype=torch.long)
        return image, label, torch.tensor(label_length, dtype=torch.long)

# %%
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(degrees=5),
    transforms.RandomAffine(degrees=0, translate=(0.05, 0.05)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.5, scale=(0.01, 0.05), ratio=(0.3, 3.3)),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

train_dataset = BalineseDataset(train_data, images_dir, transform=train_transform)
val_dataset   = BalineseDataset(val_data,   images_dir, transform=val_transform)

batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# %%
class ResNet18Encoder(nn.Module):
    """
    Encoder that uses a pretrained ResNet18 to extract features of shape 
    [B, H*W, C], which the DecoderRNN can then attend over.
    """

    def __init__(self, pretrained=True):
        super(ResNet18Encoder, self).__init__()
        resnet = models.resnet18(pretrained=pretrained)

        # Remove the classification (fc) layer
        modules = list(resnet.children())[:-2]  # remove the avgpool & fc
        self.cnn = nn.Sequential(*modules)

        # last convolutional block outputs 512 channels
        self.encoder_dim = 512

    def forward(self, x):
        """
        Input shape:  x -> [batch_size, 3, 224, 224]
        Output shape: -> [batch_size, num_patches, encoder_dim]
                       where num_patches = H' * W' from the final feature map
        """
        # pass through ResNet (up to layer4)
        features = self.cnn(x)  # [B, 512, H', W']

        # Flatten the spatial dims
        # shape => [B, 512, H', W'] -> [B, H'*W', 512]
        b, c, h, w = features.shape
        features = features.permute(0, 2, 3, 1)   # [B, H', W', C]
        features = features.reshape(b, -1, c)     # [B, H'*W', C]

        return features

# %%
class ViTEncoder(nn.Module):
    """
    A simple ViT encoder that extracts patch embeddings as [batch_size, num_patches, hidden_dim].
    We'll use timm to load a pretrained ViT. Then we use .forward_features() to get a
    feature map of shape [B, C, H', W'] for many timm ViT models, which we flatten.
    """
    def __init__(self, model_name, pretrained=True):
        super(ViTEncoder, self).__init__()
        self.vit = timm.create_model(model_name, pretrained=pretrained)
        # Remove or replace the classification head
        self.vit.head = nn.Identity()

        # timm's ViT typically has an embed_dim attribute
        self.encoder_dim = self.vit.embed_dim

    def forward(self, x):
        """
        :param x: [batch_size, 3, 224, 224]
        :return:  [batch_size, num_patches, encoder_dim]
        """
        # forward_features usually returns [B, hidden_dim, H', W'] or [B, hidden_dim]
        feats = self.vit.forward_features(x)  # [B, hidden_dim, 14, 14] for vit_base_patch16_224

        # Flatten the spatial dimensions
        if feats.dim() == 4:  # [B, C, H, W]
            b, c, h, w = feats.shape
            feats = feats.permute(0, 2, 3, 1).reshape(b, -1, c)  # => [B, H*W, C]

        return feats

# %%
class SwinEncoder(nn.Module):
    def __init__(self, model_name="swin_small_patch4_window7_224", pretrained=True):
        """
        A simple Swin Transformer encoder that extracts patch embeddings
        as [batch_size, num_patches, hidden_dim]. We'll use timm to load 
        a pretrained Swin model, remove its classification head, then flatten.
        """
        super().__init__()
        self.swin = timm.create_model(model_name, pretrained=pretrained)
        self.swin.head = nn.Identity()

        # We'll assign encoder_dim dynamically after forward
        self.encoder_dim = None

    def forward(self, x):
        """
        :param x: [batch_size, 3, 224, 224]
        :return:  [batch_size, num_patches, encoder_dim]
        """
        feats = self.swin.forward_features(x)            # [B, C, H, W]
        b, c, h, w = feats.shape
        feats = feats.flatten(2).transpose(1, 2)         # [B, H*W, C]
        # Set encoder_dim once (C)
        if self.encoder_dim is None:
            self.encoder_dim = feats.shape[-1]
        return feats

# %%
class HybridEncoder(nn.Module):
    def __init__(self, cnn_encoder, vit_encoder):
        super(HybridEncoder, self).__init__()
        self.cnn_encoder = cnn_encoder
        self.vit_encoder = vit_encoder
        # Combined encoder_dim is the sum of both encoder dimensions.
        # (CNN outputs 512 channels; ViT outputs its own embed_dim.)
        self.encoder_dim = cnn_encoder.encoder_dim + vit_encoder.encoder_dim

    def forward(self, x):
        # Get CNN features: expected shape [B, 49, 512]
        cnn_features = self.cnn_encoder(x)

        # Get ViT features: expected shape [B, 197, vit_dim] for vit_large_patch16_224
        vit_features = self.vit_encoder(x)
        # If the ViT output contains a class token, remove it.
        if vit_features.shape[1] == 197:
            vit_features = vit_features[:, 1:, :]  # Now shape: [B, 196, vit_dim]
            B, tokens, D = vit_features.shape
            # Reshape tokens into a 14x14 grid: [B, 14, 14, D]
            vit_features = vit_features.reshape(B, 14, 14, D)
            # Permute to [B, D, 14, 14] for pooling
            vit_features = vit_features.permute(0, 3, 1, 2)
            # Use adaptive pooling to reduce to a 7x7 grid
            vit_features = F.adaptive_avg_pool2d(vit_features, (7, 7))
            # Permute back to [B, 7, 7, D] and flatten to [B, 49, D]
            vit_features = vit_features.permute(0, 2, 3, 1).reshape(B, -1, D)

        # Concatenate the features along the feature dimension (dim=2)
        # cnn_features: [B, 49, 512] and vit_features: [B, 49, vit_dim]
        hybrid_features = torch.cat([cnn_features, vit_features], dim=2)
        return hybrid_features

# %%
class Attention(nn.Module):
    def __init__(self, encoder_dim, decoder_dim, attention_dim):
        super(Attention, self).__init__()
        self.encoder_att = nn.Linear(encoder_dim, attention_dim)  # transform encoder output
        self.decoder_att = nn.Linear(decoder_dim, attention_dim)  # transform decoder hidden
        self.full_att    = nn.Linear(attention_dim, 1)
        self.relu        = nn.ReLU()
        self.softmax     = nn.Softmax(dim=1)

    def forward(self, encoder_out, decoder_hidden):
        """
        encoder_out:    [batch_size, num_patches, encoder_dim]
        decoder_hidden: [batch_size, decoder_dim]
        """
        att1 = self.encoder_att(encoder_out)                  # [batch_size, num_patches, attention_dim]
        att2 = self.decoder_att(decoder_hidden).unsqueeze(1)  # [batch_size, 1, attention_dim]

        # sum -> relu -> full_att -> squeeze -> softmax
        att  = self.full_att(self.relu(att1 + att2)).squeeze(2)  # [batch_size, num_patches]
        alpha = self.softmax(att)
        # Weighted sum of the encoder_out
        attention_weighted_encoding = (encoder_out * alpha.unsqueeze(2)).sum(dim=1)  # [batch_size, encoder_dim]
        return attention_weighted_encoding, alpha

# %%
class DecoderRNN(nn.Module):
    def __init__(self, attention_dim, embed_dim, decoder_dim, vocab_size,
                 encoder_dim=768, teacher_forcing_ratio=0.5):
        super().__init__()

        self.tfr       = teacher_forcing_ratio
        self.attention = Attention(encoder_dim, decoder_dim, attention_dim)
        self.embedding = nn.Embedding(vocab_size, embed_dim)
        self.dropout   = nn.Dropout(0.5)

        self.rnn1 = nn.GRUCell(embed_dim + encoder_dim, decoder_dim)
        self.rnn2 = nn.GRUCell(decoder_dim, decoder_dim)

        self.init_h1 = nn.Linear(encoder_dim, decoder_dim)
        self.init_h2 = nn.Linear(encoder_dim, decoder_dim)

        self.f_beta  = nn.Linear(decoder_dim, encoder_dim)
        self.sigmoid = nn.Sigmoid()
        self.fc      = nn.Linear(decoder_dim, vocab_size)

        self._init_weights()

    def _init_weights(self):
        nn.init.uniform_(self.embedding.weight, -0.1, 0.1)
        nn.init.uniform_(self.fc.weight,       -0.1, 0.1)
        nn.init.zeros_(self.fc.bias)

    def init_hidden_state(self, encoder_out):
        mean_enc = encoder_out.mean(dim=1)
        h1 = self.init_h1(mean_enc)
        h2 = self.init_h2(mean_enc)
        return h1, h2

    def forward(self, encoder_out, encoded_captions, caption_lengths):
        caption_lengths, sort_ind = caption_lengths.squeeze(1).sort(0, True)
        encoder_out      = encoder_out[sort_ind]
        encoded_captions = encoded_captions[sort_ind]
        embeddings       = self.embedding(encoded_captions)

        h1, h2 = self.init_hidden_state(encoder_out)

        decode_lens = (caption_lengths - 1).tolist()
        T = max(decode_lens)
        B = encoder_out.size(0)
        V = self.fc.out_features
        P = encoder_out.size(1)

        predictions = torch.zeros(B, T, V, device=encoder_out.device)
        alphas      = torch.zeros(B, T, P, device=encoder_out.device)

        prev_tok = encoded_captions[:, 0].clone()

        for t in range(T):
            Bt = sum(l > t for l in decode_lens)

            ctx, alpha = self.attention(encoder_out[:Bt], h1[:Bt])
            gate = self.sigmoid(self.f_beta(h1[:Bt])) * ctx

            use_tf = torch.rand(1).item() < self.tfr
            cur_in = embeddings[:Bt, t] if use_tf else self.embedding(prev_tok[:Bt])
            x = torch.cat([cur_in, gate], 1)

            h1n = self.rnn1(x, h1[:Bt])
            h2n = self.rnn2(h1n, h2[:Bt])

            out                 = self.fc(self.dropout(h2n))
            predictions[:Bt, t] = out
            alphas[:Bt, t]      = alpha

            # Get next‐token and update buffer without in-place
            next_tokens = out.argmax(1).detach()
            prev_new    = prev_tok.clone()
            prev_new[:Bt] = next_tokens
            prev_tok    = prev_new

            # Update hidden states safely (as before)
            h1_new = h1.clone(); h1_new[:Bt] = h1n
            h2_new = h2.clone(); h2_new[:Bt] = h2n
            h1, h2 = h1_new, h2_new
        return predictions, encoded_captions, decode_lens, alphas, sort_ind

# %%
class ImageCaptioningTrainer:
    def __init__(self, encoder, decoder, 
                 criterion, encoder_optimizer, decoder_optimizer, 
                 train_loader, val_loader, test_loader, test_data, max_label_length_test,
                 device, char_to_idx, idx_to_char, max_label_length,
                 model_name, csv_filename="training_results.csv"):
        self.encoder = encoder.to(device)
        self.decoder = decoder.to(device)
        self.criterion = criterion
        self.encoder_optimizer = encoder_optimizer
        self.decoder_optimizer = decoder_optimizer
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.test_loader = test_loader
        self.test_data = test_data
        self.max_label_length_test = max_label_length_test
        self.device = device
        self.char_to_idx = char_to_idx
        self.idx_to_char = idx_to_char
        self.max_label_length = max_label_length
        self.model_name = model_name
        self.csv_filename = csv_filename

        self.train_losses = []
        self.val_losses = []
        self.train_cers = []
        self.val_cers = []
        self.test_cers = []

    # def fit(self, num_epochs):
    #     start_time = time.time()
        
    #     # Early stopping parameters
    #     best_val_loss = float('inf')
    #     early_stop_counter = 0
    #     early_stop_patience = 6

    #     for epoch in range(num_epochs):
    #         print(f"\nEpoch {epoch + 1}/{num_epochs}")
    #         train_loss, train_cer = self.train_one_epoch()
    #         val_loss, val_cer = self.validate_one_epoch(top_n=5)

    #         print(f"[{epoch+1}/{num_epochs}] "
    #               f"Train Loss: {train_loss:.4f}, Train CER: {train_cer:.4f} | "
    #               f"Val Loss: {val_loss:.4f}, Val CER: {val_cer:.4f}")

    #         # Store epoch results
    #         self.train_losses.append(train_loss)
    #         self.val_losses.append(val_loss)
    #         self.train_cers.append(train_cer)
    #         self.val_cers.append(val_cer)
            
    #         # Early stopping check: if current val_loss is better, reset counter; otherwise, increment.
    #         if val_loss < best_val_loss:
    #             best_val_loss = val_loss
    #             early_stop_counter = 0
    #         else:
    #             early_stop_counter += 1
    #             print(f"Validation loss did not improve. Early stop counter: {early_stop_counter}/{early_stop_patience}")
            
    #         if early_stop_counter >= early_stop_patience:
    #             print("Early stopping triggered.")
    #             break
        
    #     # Calculate total training time
    #     end_time = time.time() 
    #     total_time = end_time - start_time
    #     hours = int(total_time // 3600)
    #     minutes = int((total_time % 3600) // 60)

    #     print(f"\nTraining completed in {hours}h {minutes}m.")

    #     num_epochs_recorded = len(self.train_losses)
    #     epoch_cols = [f"epoch{i+1}" for i in range(num_epochs_recorded)]

    #     # Create the new data block to insert
    #     new_rows = pd.DataFrame([
    #         [self.model_name, "training loss"] + self.train_losses,
    #         [self.model_name, "validation loss"] + self.val_losses,
    #         [self.model_name, "training cer"] + self.train_cers,
    #         [self.model_name, "validation cer"] + self.val_cers
    #     ], columns=["model_name", "mode"] + epoch_cols)
        
    #     # Check if CSV already exists
    #     if os.path.exists(self.csv_filename):
    #         df_existing = pd.read_csv(self.csv_filename)
    #         df_existing = df_existing[df_existing["model_name"] != self.model_name]
    #         df_updated = pd.concat([df_existing, new_rows], ignore_index=True)
    #     else:
    #         df_updated = new_rows

    #     df_updated[epoch_cols] = np.floor(df_updated[epoch_cols] * 100) / 100 
        
    #     # Save the updated CSV
    #     df_updated.to_csv(self.csv_filename, index=False)
    #     print(f"\nResults have been written to: {self.csv_filename}")

    #     # Save model weights
    #     # torch.save(self.encoder.state_dict(), f"encoder_{self.model_name}.pth")
    #     # torch.save(self.decoder.state_dict(), f"decoder_{self.model_name}.pth")
    #     # print(f"Encoder and decoder models saved: encoder_{self.model_name}.pth, decoder_{self.model_name}.pth")
    
    def fit(self, num_epochs):
        start_time = time.time()
        best_test_cer = float('inf')
        early_stop_counter = 0
        early_stop_patience = 3
    
        for epoch in range(num_epochs):
            print(f"\nEpoch {epoch + 1}/{num_epochs}")
            train_loss, train_cer = self.train_one_epoch()
            val_loss, val_cer = self.validate_one_epoch()
    
            results = inference(
                encoder=self.encoder,
                decoder=self.decoder,
                data_loader=self.test_loader,
                device=self.device,
                char_to_idx=self.char_to_idx,
                idx_to_char=self.idx_to_char,
                max_seq_length=self.max_label_length_test,
                test_data=self.test_data
            )
            test_cer = calculate_global_cer(results)
    
            print(f"[{epoch+1}/{num_epochs}] "
                  f"Train Loss: {train_loss:.4f}, Train CER: {train_cer:.4f} | "
                  f"Val Loss: {val_loss:.4f}, Val CER: {val_cer:.4f} | "
                  f"Test CER: {test_cer:.4f}")
    
            self.train_losses.append(train_loss)
            self.val_losses.append(val_loss)
            self.train_cers.append(train_cer)
            self.val_cers.append(val_cer)
            self.test_cers.append(test_cer)
    
            if test_cer < best_test_cer:
                best_test_cer = test_cer
                early_stop_counter = 0
            else:
                early_stop_counter += 1
                print(f"Test CER did not improve. Early stop counter: {early_stop_counter}/{early_stop_patience}")
            
            if early_stop_counter >= early_stop_patience:
                print("Early stopping triggered.")
                break
    
        total_time = time.time() - start_time
        hours = int(total_time // 3600)
        minutes = int((total_time % 3600) // 60)
        print(f"\nTraining completed in {hours}h {minutes}m.")
    
        # Save CSV
        num_epochs_recorded = len(self.train_losses)
        epoch_cols = [f"epoch{i+1}" for i in range(num_epochs_recorded)]
    
        new_rows = pd.DataFrame([
            [self.model_name, "training loss"] + self.train_losses,
            [self.model_name, "validation loss"] + self.val_losses,
            [self.model_name, "training cer"] + self.train_cers,
            [self.model_name, "validation cer"] + self.val_cers,
            [self.model_name, "test cer"] + self.test_cers
        ], columns=["model_name", "mode"] + epoch_cols)
    
        if os.path.exists(self.csv_filename):
            df_existing = pd.read_csv(self.csv_filename)
            df_existing = df_existing[df_existing["model_name"] != self.model_name]
            df_updated = pd.concat([df_existing, new_rows], ignore_index=True)
        else:
            df_updated = new_rows
    
        df_updated[epoch_cols] = np.floor(df_updated[epoch_cols] * 100) / 100 
        df_updated.to_csv(self.csv_filename, index=False)
        print(f"\nResults have been written to: {self.csv_filename}")

    def train_one_epoch(self):
        self.encoder.train()
        self.decoder.train()
        running_loss           = 0.0
        total_edit_distance    = 0
        total_ref_length       = 0

        for batch_idx, (images, labels, label_lengths) in enumerate(self.train_loader):
            images        = images.to(self.device, non_blocking=True)
            labels        = labels.to(self.device, non_blocking=True)
            label_lengths = label_lengths.to(self.device, non_blocking=True)

            self.encoder_optimizer.zero_grad()
            self.decoder_optimizer.zero_grad()

            encoder_out   = self.encoder(images)
            caption_lengths = torch.tensor(
                [self.max_label_length] * labels.size(0)
            ).unsqueeze(1).to(self.device)

            outputs, encoded_captions, decode_lengths, alphas, sort_ind = self.decoder(
                encoder_out, labels, caption_lengths
            )

            # Targets = encoded captions without the <SOS>
            targets = encoded_captions[:, 1:]

            # Flatten for loss
            outputs_flat = outputs.view(-1, self.decoder.fc.out_features)
            targets_flat = targets.contiguous().view(-1)

            loss = self.criterion(outputs_flat, targets_flat)
            loss.backward()

            self.decoder_optimizer.step()
            self.encoder_optimizer.step()

            running_loss += loss.item()

            # Compute CER for the batch (global style)
            batch_size = labels.size(0)
            _, preds_flat = torch.max(outputs_flat, dim=1)
            preds_seq = preds_flat.view(batch_size, -1)

            for i in range(batch_size):
                pred_indices   = preds_seq[i].detach().cpu().numpy()
                target_indices = targets[i].detach().cpu().numpy()

                mask          = (target_indices != self.char_to_idx['<PAD>'])
                pred_indices  = pred_indices[mask]
                target_indices= target_indices[mask]

                pred_chars    = [self.idx_to_char.get(idx, '') for idx in pred_indices]
                target_chars  = [self.idx_to_char.get(idx, '') for idx in target_indices]
                pred_str      = ''.join(pred_chars)
                target_str    = ''.join(target_chars)

                edit_dist           = editdistance.eval(pred_str, target_str)
                total_edit_distance += edit_dist
                total_ref_length    += len(target_str)

            # if (batch_idx + 1) % 50 == 0:
            #     print(f'Batch {batch_idx + 1}/{len(self.train_loader)} - Loss: {loss.item():.4f}')

        avg_loss = running_loss / len(self.train_loader)
        avg_cer  = total_edit_distance / total_ref_length if total_ref_length > 0 else 0.0
        return avg_loss, avg_cer

    def validate_one_epoch(self, top_n=5):
        self.encoder.eval()
        self.decoder.eval()
        running_loss         = 0.0
        total_edit_distance  = 0
        total_ref_length     = 0

        # each sample’s CER
        sample_cer_info = []

        with torch.no_grad():
            for batch_idx, (images, labels, label_lengths) in enumerate(self.val_loader):
                images        = images.to(self.device, non_blocking=True)
                labels        = labels.to(self.device, non_blocking=True)
                label_lengths = label_lengths.to(self.device, non_blocking=True)

                encoder_out = self.encoder(images)
                caption_lengths = torch.tensor(
                    [self.max_label_length] * labels.size(0)
                ).unsqueeze(1).to(self.device)

                outputs, encoded_captions, decode_lengths, alphas, sort_ind = self.decoder(
                    encoder_out, labels, caption_lengths
                )
                targets = encoded_captions[:, 1:]

                outputs_flat = outputs.view(-1, self.decoder.fc.out_features)
                targets_flat = targets.contiguous().view(-1)

                loss = self.criterion(outputs_flat, targets_flat)
                running_loss += loss.item()

                batch_size = labels.size(0)
                _, preds_flat = torch.max(outputs_flat, dim=1)
                preds_seq = preds_flat.view(batch_size, -1)

                for i in range(batch_size):
                    pred_indices   = preds_seq[i].detach().cpu().numpy()
                    target_indices = targets[i].detach().cpu().numpy()

                    mask           = (target_indices != self.char_to_idx['<PAD>'])
                    pred_indices   = pred_indices[mask]
                    target_indices = target_indices[mask]

                    pred_chars   = [self.idx_to_char.get(idx, '') for idx in pred_indices]
                    target_chars = [self.idx_to_char.get(idx, '') for idx in target_indices]
                    pred_str     = ''.join(pred_chars)
                    target_str   = ''.join(target_chars)

                    edit_dist = editdistance.eval(pred_str, target_str)
                    ref_len   = len(target_str)
                    cer       = edit_dist / ref_len if ref_len > 0 else 0
    
                    total_edit_distance += edit_dist
                    total_ref_length    += ref_len
    
                    # Store sample info
                    # sample_cer_info.append({
                    #     "pred": pred_str,
                    #     "gt": target_str,
                    #     "cer": cer
                    # })

                    # Print a few samples from the 1st batch
                    # if batch_idx == 0 and i < 3:
                    #     print(f"Sample {i + 1}:")
                    #     print(f"Predicted: {pred_str}")
                    #     print(f"Target   : {target_str}\n")

        avg_loss = running_loss / len(self.val_loader)
        avg_cer  = total_edit_distance / total_ref_length if total_ref_length > 0 else 0.0

        # Sort by CER descending
        sample_cer_info.sort(key=lambda x: x["cer"], reverse=True)
        # Take top_n
        worst_samples = sample_cer_info[:top_n]
    
        # print(f"\n=== Top {top_n} Worst Samples by CER ===")
        # for idx, sample in enumerate(worst_samples):
        #     print(f"[{idx+1}] CER: {sample['cer']:.3f}")
        #     print(f"   Predicted: {sample['pred']}")
        #     print(f"   Ground Truth: {sample['gt']}\n")
       
        return avg_loss, avg_cer

# %%
test_ground_truth_path = os.path.join(DATA_DIR, 'balinese_transliteration_test.txt')
test_images_dir        = os.path.join(DATA_DIR, 'balinese_word_test')

test_filenames = []
test_labels    = []

with open(test_ground_truth_path, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        if line:
            parts = line.split(';')
            if len(parts) == 2:
                filename, label = parts
                label = label.lower()
                test_filenames.append(filename)
                test_labels.append(label)
            else:
                print(f"Skipping malformed line: {line}")

test_data = pd.DataFrame({
    'filename': test_filenames,
    'label': test_labels
})

# Check for unknown chars in test set
test_chars = set(''.join(test_data['label']))
unknown_chars = test_chars - set(char_to_idx.keys())
print(f"Unknown characters in test labels: {unknown_chars}")

# Encode test labels
max_label_length_test = max(len(lbl) for lbl in test_data['label']) + 2
def encode_label_test(label, char_to_idx, max_length):
    encoded = (
        [char_to_idx['<SOS>']] +
        [char_to_idx.get(ch, char_to_idx['<UNK>']) for ch in label] +
        [char_to_idx['<EOS>']]
    )
    if len(encoded) > max_length:
        encoded = encoded[:max_length]
    else:
        encoded += [char_to_idx['<PAD>']] * (max_length - len(encoded))
    return encoded

test_data['encoded_label'] = test_data['label'].apply(lambda x: encode_label_test(x, char_to_idx, max_label_length_test))
test_data['label_length']  = test_data['label'].apply(len)

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.5, 0.5, 0.5),
        std=(0.5, 0.5, 0.5)
    )
])

test_dataset = BalineseDataset(test_data, test_images_dir, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)
# Out:
# Unknown characters in test labels: set()

# %%
def inference(encoder, decoder, data_loader, device, char_to_idx, idx_to_char, max_seq_length, test_data):
    encoder.eval()
    decoder.eval()

    eos_idx = char_to_idx['<EOS>']
    results = []

    with torch.no_grad():
        for batch_idx, (images, labels, label_lengths) in enumerate(data_loader):
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            batch_size = images.size(0)
            encoder_out = encoder(images)  # [B, num_patches, encoder_dim]

            h1, h2 = decoder.init_hidden_state(encoder_out)

            # Start tokens (all <SOS>)
            inputs = torch.full(
                (batch_size,),
                fill_value=char_to_idx['<SOS>'],
                dtype=torch.long,
                device=device
            )

            all_preds = []

            for _ in range(max_seq_length):
                embeddings = decoder.embedding(inputs)
                attn_ctx, _ = decoder.attention(encoder_out, h1)
                gate = decoder.sigmoid(decoder.f_beta(h1))
                attn_ctx = gate * attn_ctx
                x = torch.cat([embeddings, attn_ctx], dim=1)

                h1 = decoder.rnn1(x, h1)
                h2 = decoder.rnn2(h1, h2)

                logits = decoder.fc(decoder.dropout(h2))
                preds_idx = logits.argmax(dim=1)

                all_preds.append(preds_idx.cpu().numpy())
                inputs = preds_idx

            all_preds = np.array(all_preds).T

            for i in range(batch_size):
                pred_indices = all_preds[i]
                if eos_idx in pred_indices:
                    pred_indices = pred_indices[:np.where(pred_indices == eos_idx)[0][0]]

                pred_str = ''.join([idx_to_char.get(idx, '') for idx in pred_indices])

                label_indices = labels[i].cpu().numpy()[1:]  # remove <SOS>
                if eos_idx in label_indices:
                    label_indices = label_indices[:np.where(label_indices == eos_idx)[0][0]]
                else:
                    label_indices = label_indices[label_indices != char_to_idx['<PAD>']]

                label_str = ''.join([idx_to_char.get(idx, '') for idx in label_indices])
                image_filename = test_data.iloc[batch_idx * batch_size + i]['filename']

                results.append({
                    'image_filename': image_filename,
                    'predicted_caption': pred_str,
                    'ground_truth_caption': label_str
                })

    return results

# %%
def calculate_global_cer(results):
    total_ed   = 0
    total_refs = 0
    for r in results:
        ref = r['ground_truth_caption']
        hyp = r['predicted_caption']
        dist = editdistance.eval(ref, hyp)
        total_ed   += dist
        total_refs += len(ref)
    if total_refs == 0:
        return 0.0
    return total_ed / total_refs

# %%
def print_top_worst_samples(results, n=5):
    # Calculate CER for each sample
    results_with_cer = []
    for r in results:
        ref = r['ground_truth_caption']
        hyp = r['predicted_caption']
        dist = editdistance.eval(ref, hyp)
        length = len(ref)
        cer = dist / length if length > 0 else 0
        # Copy the record and add cer
        new_r = r.copy()
        new_r['cer'] = cer
        results_with_cer.append(new_r)

    # Sort by CER (descending) and take the top N
    results_with_cer.sort(key=lambda x: x['cer'], reverse=True)
    worst_samples = results_with_cer[:n]

    print(f"\n=== Top {n} Worst Samples by CER ===")
    for i, sample in enumerate(worst_samples, start=1):
        print(f"{i}) Image: {sample['image_filename']}")
        print(f"   CER: {sample['cer']:.4f}")
        print(f"   Predicted       : {sample['predicted_caption']}")
        print(f"   Ground Truth    : {sample['ground_truth_caption']}")
        print()

# %%
# Ensure CSV files exist
training_csv = "training_results.csv"
if not os.path.exists(training_csv) or os.path.getsize(training_csv) == 0:
    pd.DataFrame(columns=["model_name", "mode", "epoch1", "epoch2"]).to_csv(training_csv, index=False)

csv_file = "test_cer_results.csv"
if not os.path.exists(csv_file) or os.path.getsize(csv_file) == 0:
    pd.DataFrame(columns=["model_name", "test_cer"]).to_csv(csv_file, index=False)

def log_test_cer(model_name, cer_value):
    """
    Logs or updates the test CER for a given model, rounding values to 4 decimals.
    """
    df = pd.read_csv(csv_file)
    
    # Round the new CER value to 4 decimals
    cer_rounded = round(cer_value, 4)
    
    if model_name in df['model_name'].values:
        # Update existing row
        df.loc[df['model_name'] == model_name, 'test_cer'] = cer_rounded
    else:
        # Add new row
        new_row = pd.DataFrame({
            "model_name": [model_name],
            "test_cer":   [cer_rounded]
        })
        df = pd.concat([df, new_row], ignore_index=True)
    
    # Ensure all stored values are rounded to 4 decimals
    df['test_cer'] = df['test_cer'].round(4)
    
    # Save back to CSV
    df.to_csv(csv_file, index=False)
    print(f"Logged {model_name}: {cer_rounded:.4f}")

# %%
def run_training_pipeline(encoder_class,encoder_kwargs, model_name,vocab_size,encoder_lr, decoder_lr,train_loader,
                          val_loader,test_loader,char_to_idx,idx_to_char,max_label_length,max_label_length_test,test_data,
                          device, num_epochs=50):
    #build encoder & grab its dimension
    encoder = encoder_class(**encoder_kwargs).to(device)
    # if encoder_dim is None (e.g. Swin), prime it with a dummy batch
    if encoder.encoder_dim is None:
        with torch.no_grad():
            dummy = torch.randn(1, 3, 224, 224, device=device)
            _ = encoder(dummy)
    enc_dim = encoder.encoder_dim

    #build decoder 
    decoder = DecoderRNN(
        attention_dim=256,
        embed_dim=256,
        decoder_dim=512,
        vocab_size=vocab_size,
        encoder_dim=enc_dim,
        teacher_forcing_ratio=0.5
    ).to(device)

    # loss, optimizers, trainer
    criterion = nn.CrossEntropyLoss(ignore_index=char_to_idx['<PAD>'])
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=encoder_lr)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=decoder_lr)

    # trainer = ImageCaptioningTrainer(
    #     encoder=encoder,
    #     decoder=decoder,
    #     criterion=criterion,
    #     encoder_optimizer=encoder_optimizer,
    #     decoder_optimizer=decoder_optimizer,
    #     train_loader=train_loader,
    #     val_loader=val_loader,
    #     device=device,
    #     char_to_idx=char_to_idx,
    #     idx_to_char=idx_to_char,
    #     max_label_length=max_label_length,
    #     model_name=model_name)
    trainer = ImageCaptioningTrainer(
        encoder=encoder,
        decoder=decoder,
        criterion=criterion,
        encoder_optimizer=encoder_optimizer,
        decoder_optimizer=decoder_optimizer,
        train_loader=train_loader,
        val_loader=val_loader,
        test_loader=test_loader,  
        test_data=test_data,      
        max_label_length_test=max_label_length_test,  
        device=device,
        char_to_idx=char_to_idx,
        idx_to_char=idx_to_char,
        max_label_length=max_label_length,
        model_name=model_name
    )

    trainer.fit(num_epochs)

    encoder.eval()
    decoder.teacher_forcing_ratio = 0.0

    results = inference(
        encoder=encoder,
        decoder=decoder,
        data_loader=test_loader,
        device=device,
        char_to_idx=char_to_idx,
        idx_to_char=idx_to_char,
        max_seq_length=max_label_length_test,
        test_data=test_data
    )

    cer = calculate_global_cer(results)
    print(f"{model_name} — Test CER: {cer:.4f}")
    print_top_worst_samples(results, n=5)
    log_test_cer(model_name, cer)

    del encoder, decoder, trainer
    torch.cuda.empty_cache()
    print(f"Memory cleared for {model_name}")

# %%
run_training_pipeline(
    encoder_class = ResNet18Encoder,
    encoder_kwargs= {},                              
    model_name    = "resnet18_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50
# [1/50] Train Loss: 1.9431, Train CER: 0.6459 | Val Loss: 1.0624, Val CER: 0.3797 | Test CER: 0.4810
#
# Epoch 2/50
# [2/50] Train Loss: 1.1622, Train CER: 0.3449 | Val Loss: 0.5599, Val CER: 0.1474 | Test CER: 0.2940
#
# Epoch 3/50
# [3/50] Train Loss: 0.8153, Train CER: 0.2287 | Val Loss: 0.3832, Val CER: 0.1180 | Test CER: 0.2430
#
# Epoch 4/50
# [4/50] Train Loss: 0.6200, Train CER: 0.1695 | Val Loss: 0.3429, Val CER: 0.0857 | Test CER: 0.2044
#
# Epoch 5/50
# [5/50] Train Loss: 0.5040, Train CER: 0.1368 | Val Loss: 0.2643, Val CER: 0.0738 | Test CER: 0.1856
#
# Epoch 6/50
# [6/50] Train Loss: 0.4317, Train CER: 0.1174 | Val Loss: 0.2657, Val CER: 0.0791 | Test CER: 0.1795
#
# Epoch 7/50
# [7/50] Train Loss: 0.3660, Train CER: 0.1006 | Val Loss: 0.2303, Val CER: 0.0644 | Test CER: 0.1758
#
# Epoch 8/50
# [8/50] Train Loss: 0.3137, Train CER: 0.0842 | Val Loss: 0.2546, Val CER: 0.0675 | Test CER: 0.1694
#
# Epoch 9/50
# [9/50] Train Loss: 0.2759, Train CER: 0.0732 | Val Loss: 0.2403, Val CER: 0.0648 | Test CER: 0.1601
#
# Epoch 10/50
# [10/50] Train Loss: 0.2392, Train CER: 0.0628 | Val Loss: 0.2540, Val CER: 0.0656 | Test CER: 0.1645
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 11/50
# [11/50] Train Loss: 0.2256, Train CER: 0.0589 | Val Loss: 0.2472, Val CER: 0.0616 | Test CER: 0.1621
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 12/50
# [12/50] Train Loss: 0.1948, Train CER: 0.0519 | Val Loss: 0.2405, Val CER: 0.0567 | Test CER: 0.1502
#
# Epoch 13/50
# [13/50] Train Loss: 0.1773, Train CER: 0.0483 | Val Loss: 0.2206, Val CER: 0.0609 | Test CER: 0.1524
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 14/50
# [14/50] Train Loss: 0.1620, Train CER: 0.0436 | Val Loss: 0.2512, Val CER: 0.0556 | Test CER: 0.1536
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 15/50
# [15/50] Train Loss: 0.1331, Train CER: 0.0347 | Val Loss: 0.2445, Val CER: 0.0584 | Test CER: 0.1527
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 0h 19m.
#
# Results have been written to: training_results.csv
# resnet18_encoder — Test CER: 0.1527
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 9.0000
#    Predicted       : pangannya
#    Ground Truth    : .
#
# 2) Image: test580.png
#    CER: 7.0000
#    Predicted       : warania
#    Ground Truth    : .
#
# 3) Image: test2856.png
#    CER: 6.0000
#    Predicted       : bebaba
#    Ground Truth    : .
#
# 4) Image: test8296.png
#    CER: 6.0000
#    Predicted       : sanggi
#    Ground Truth    : .
#
# 5) Image: test1335.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# Logged resnet18_encoder: 0.1527
# Memory cleared for resnet18_encoder

# %%
run_training_pipeline(
    encoder_class = ViTEncoder,
    encoder_kwargs= {"model_name":"vit_base_patch16_224","pretrained":True},
    model_name    = "vit_base_patch16_224",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/50
# [1/50] Train Loss: 1.9370, Train CER: 0.6384 | Val Loss: 1.0418, Val CER: 0.2789 | Test CER: 0.4787
#
# Epoch 2/50
# [2/50] Train Loss: 1.0690, Train CER: 0.3212 | Val Loss: 0.4986, Val CER: 0.1501 | Test CER: 0.2736
#
# Epoch 3/50
# [3/50] Train Loss: 0.7255, Train CER: 0.2010 | Val Loss: 0.3847, Val CER: 0.1078 | Test CER: 0.2103
#
# Epoch 4/50
# [4/50] Train Loss: 0.6262, Train CER: 0.1708 | Val Loss: 0.3014, Val CER: 0.0777 | Test CER: 0.1798
#
# Epoch 5/50
# [5/50] Train Loss: 0.4835, Train CER: 0.1278 | Val Loss: 0.2561, Val CER: 0.0719 | Test CER: 0.1607
#
# Epoch 6/50
# [6/50] Train Loss: 0.4359, Train CER: 0.1173 | Val Loss: 0.3448, Val CER: 0.0898 | Test CER: 0.1969
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 7/50
# [7/50] Train Loss: 0.4102, Train CER: 0.1065 | Val Loss: 0.2372, Val CER: 0.0606 | Test CER: 0.1495
#
# Epoch 8/50
# [8/50] Train Loss: 0.3468, Train CER: 0.0917 | Val Loss: 0.2627, Val CER: 0.0723 | Test CER: 0.1575
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 9/50
# [9/50] Train Loss: 0.2978, Train CER: 0.0774 | Val Loss: 0.2193, Val CER: 0.0560 | Test CER: 0.1353
#
# Epoch 10/50
# [10/50] Train Loss: 0.2801, Train CER: 0.0740 | Val Loss: 0.2041, Val CER: 0.0521 | Test CER: 0.1395
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 11/50
# [11/50] Train Loss: 0.2352, Train CER: 0.0621 | Val Loss: 0.2043, Val CER: 0.0499 | Test CER: 0.1352
#
# Epoch 12/50
# [12/50] Train Loss: 0.2559, Train CER: 0.0670 | Val Loss: 0.2169, Val CER: 0.0530 | Test CER: 0.1326
#
# Epoch 13/50
# [13/50] Train Loss: 0.2671, Train CER: 0.0698 | Val Loss: 0.2428, Val CER: 0.0654 | Test CER: 0.1465
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 14/50
# [14/50] Train Loss: 0.2302, Train CER: 0.0577 | Val Loss: 0.1767, Val CER: 0.0474 | Test CER: 0.1230
#
# Epoch 15/50
# [15/50] Train Loss: 0.1788, Train CER: 0.0455 | Val Loss: 0.1968, Val CER: 0.0547 | Test CER: 0.1395
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 16/50
# [16/50] Train Loss: 0.1677, Train CER: 0.0421 | Val Loss: 0.1820, Val CER: 0.0489 | Test CER: 0.1343
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 17/50
# [17/50] Train Loss: 0.1659, Train CER: 0.0401 | Val Loss: 0.2022, Val CER: 0.0533 | Test CER: 0.1300
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 0h 49m.
#
# Results have been written to: training_results.csv
# vit_base_patch16_224 — Test CER: 0.1300
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 9.0000
#    Predicted       : pangkiala
#    Ground Truth    : .
#
# 2) Image: test4436.png
#    CER: 7.0000
#    Predicted       : marik-a
#    Ground Truth    : .
#
# 3) Image: test858.png
#    CER: 6.0000
#    Predicted       : hangya
#    Ground Truth    : .
#
# 4) Image: test7927.png
#    CER: 6.0000
#    Predicted       : pantia
#    Ground Truth    : .
#
# 5) Image: test1335.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# Logged vit_base_patch16_224: 0.1300
# Memory cleared for vit_base_patch16_224

# %%
run_training_pipeline(
    encoder_class = ViTEncoder,
    encoder_kwargs= {"model_name": "vit_large_patch16_224", "pretrained": True},
    model_name    = "vit_large_patch16_224",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/50
# [1/50] Train Loss: 1.8865, Train CER: 0.6289 | Val Loss: 0.8081, Val CER: 0.2382 | Test CER: 0.3879
#
# Epoch 2/50
# [2/50] Train Loss: 0.9378, Train CER: 0.2840 | Val Loss: 0.4518, Val CER: 0.1254 | Test CER: 0.2358
#
# Epoch 3/50
# [3/50] Train Loss: 0.6547, Train CER: 0.1836 | Val Loss: 0.3527, Val CER: 0.0940 | Test CER: 0.2031
#
# Epoch 4/50
# [4/50] Train Loss: 0.5183, Train CER: 0.1407 | Val Loss: 0.2615, Val CER: 0.0674 | Test CER: 0.1593
#
# Epoch 5/50
# [5/50] Train Loss: 0.4431, Train CER: 0.1197 | Val Loss: 0.2382, Val CER: 0.0625 | Test CER: 0.1491
#
# Epoch 6/50
# [6/50] Train Loss: 0.3790, Train CER: 0.1010 | Val Loss: 0.2460, Val CER: 0.0655 | Test CER: 0.1597
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 7/50
# [7/50] Train Loss: 0.3110, Train CER: 0.0816 | Val Loss: 0.2484, Val CER: 0.0620 | Test CER: 0.1473
#
# Epoch 8/50
# [8/50] Train Loss: 0.3057, Train CER: 0.0789 | Val Loss: 0.2126, Val CER: 0.0533 | Test CER: 0.1351
#
# Epoch 9/50
# [9/50] Train Loss: 0.2766, Train CER: 0.0715 | Val Loss: 0.2347, Val CER: 0.0607 | Test CER: 0.1227
#
# Epoch 10/50
# [10/50] Train Loss: 0.2321, Train CER: 0.0601 | Val Loss: 0.2174, Val CER: 0.0508 | Test CER: 0.1291
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 11/50
# [11/50] Train Loss: 0.2335, Train CER: 0.0608 | Val Loss: 0.2095, Val CER: 0.0582 | Test CER: 0.1391
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 12/50
# [12/50] Train Loss: 0.2129, Train CER: 0.0562 | Val Loss: 0.1863, Val CER: 0.0485 | Test CER: 0.1158
#
# Epoch 13/50
# [13/50] Train Loss: 0.1972, Train CER: 0.0511 | Val Loss: 0.2177, Val CER: 0.0640 | Test CER: 0.1485
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 14/50
# [14/50] Train Loss: 0.1970, Train CER: 0.0502 | Val Loss: 0.2210, Val CER: 0.0586 | Test CER: 0.1322
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 15/50
# [15/50] Train Loss: 0.1779, Train CER: 0.0451 | Val Loss: 0.1811, Val CER: 0.0512 | Test CER: 0.1391
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 1h 58m.
#
# Results have been written to: training_results.csv
# vit_large_patch16_224 — Test CER: 0.1391
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test427.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 2) Image: test3617.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 3) Image: test5886.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 4) Image: test1330.png
#    CER: 8.0000
#    Predicted       : santiara
#    Ground Truth    : .
#
# 5) Image: test783.png
#    CER: 6.0000
#    Predicted       : tahing
#    Ground Truth    : l
#
# Logged vit_large_patch16_224: 0.1391
# Memory cleared for vit_large_patch16_224

# %%
run_training_pipeline(
    encoder_class = HybridEncoder,
    encoder_kwargs= {
        "cnn_encoder": ResNet18Encoder(pretrained=True),
        "vit_encoder": ViTEncoder(model_name="vit_base_patch16_224", pretrained=True)
    },
    model_name    = "hybrid_cnn_vit_base_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50
# [1/50] Train Loss: 1.9419, Train CER: 0.6436 | Val Loss: 0.9671, Val CER: 0.2743 | Test CER: 0.4392
#
# Epoch 2/50
# [2/50] Train Loss: 1.1081, Train CER: 0.3338 | Val Loss: 0.5716, Val CER: 0.1664 | Test CER: 0.3094
#
# Epoch 3/50
# [3/50] Train Loss: 0.7562, Train CER: 0.2161 | Val Loss: 0.3822, Val CER: 0.1051 | Test CER: 0.2224
#
# Epoch 4/50
# [4/50] Train Loss: 0.5900, Train CER: 0.1627 | Val Loss: 0.3517, Val CER: 0.0973 | Test CER: 0.2047
#
# Epoch 5/50
# [5/50] Train Loss: 0.4857, Train CER: 0.1340 | Val Loss: 0.2867, Val CER: 0.0789 | Test CER: 0.1795
#
# Epoch 6/50
# [6/50] Train Loss: 0.4083, Train CER: 0.1145 | Val Loss: 0.2535, Val CER: 0.0728 | Test CER: 0.1751
#
# Epoch 7/50
# [7/50] Train Loss: 0.3574, Train CER: 0.0943 | Val Loss: 0.2428, Val CER: 0.0698 | Test CER: 0.1643
#
# Epoch 8/50
# [8/50] Train Loss: 0.2989, Train CER: 0.0802 | Val Loss: 0.2516, Val CER: 0.0669 | Test CER: 0.1641
#
# Epoch 9/50
# [9/50] Train Loss: 0.2573, Train CER: 0.0691 | Val Loss: 0.2669, Val CER: 0.0742 | Test CER: 0.1690
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 10/50
# [10/50] Train Loss: 0.2372, Train CER: 0.0620 | Val Loss: 0.2524, Val CER: 0.0740 | Test CER: 0.1554
#
# Epoch 11/50
# [11/50] Train Loss: 0.2148, Train CER: 0.0580 | Val Loss: 0.2327, Val CER: 0.0622 | Test CER: 0.1534
#
# Epoch 12/50
# [12/50] Train Loss: 0.1855, Train CER: 0.0496 | Val Loss: 0.2417, Val CER: 0.0598 | Test CER: 0.1481
#
# Epoch 13/50
# [13/50] Train Loss: 0.1858, Train CER: 0.0515 | Val Loss: 0.2574, Val CER: 0.0604 | Test CER: 0.1520
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 14/50
# [14/50] Train Loss: 0.1610, Train CER: 0.0431 | Val Loss: 0.2886, Val CER: 0.0815 | Test CER: 0.1572
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 15/50
# [15/50] Train Loss: 0.1407, Train CER: 0.0369 | Val Loss: 0.2431, Val CER: 0.0612 | Test CER: 0.1471
#
# Epoch 16/50
# [16/50] Train Loss: 0.1349, Train CER: 0.0365 | Val Loss: 0.2560, Val CER: 0.0623 | Test CER: 0.1420
#
# Epoch 17/50
# [17/50] Train Loss: 0.1321, Train CER: 0.0353 | Val Loss: 0.2238, Val CER: 0.0570 | Test CER: 0.1548
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 18/50
# [18/50] Train Loss: 0.1301, Train CER: 0.0330 | Val Loss: 0.2571, Val CER: 0.0638 | Test CER: 0.1505
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 19/50
# [19/50] Train Loss: 0.1000, Train CER: 0.0248 | Val Loss: 0.2586, Val CER: 0.0575 | Test CER: 0.1484
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 0h 57m.
#
# Results have been written to: training_results.csv
# hybrid_cnn_vit_base_encoder — Test CER: 0.1484
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test6411.png
#    CER: 8.0000
#    Predicted       : siaringa
#    Ground Truth    : .
#
# 2) Image: test10070.png
#    CER: 8.0000
#    Predicted       : ingpania
#    Ground Truth    : .
#
# 3) Image: test1330.png
#    CER: 7.0000
#    Predicted       : angaaca
#    Ground Truth    : .
#
# 4) Image: test8296.png
#    CER: 7.0000
#    Predicted       : bying-a
#    Ground Truth    : .
#
# 5) Image: test1011.png
#    CER: 6.0000
#    Predicted       : barik-
#    Ground Truth    : .
#
# Logged hybrid_cnn_vit_base_encoder: 0.1484
# Memory cleared for hybrid_cnn_vit_base_encoder

# %%
run_training_pipeline(
    encoder_class = HybridEncoder,
    encoder_kwargs= {
        "cnn_encoder": ResNet18Encoder(pretrained=True),
        "vit_encoder": ViTEncoder(model_name="vit_large_patch16_224", pretrained=True)
    },
    model_name    = "hybrid_cnn_vit_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/50
# [1/50] Train Loss: 1.9709, Train CER: 0.6544 | Val Loss: 1.0469, Val CER: 0.2808 | Test CER: 0.4565
#
# Epoch 2/50
# [2/50] Train Loss: 1.0885, Train CER: 0.3235 | Val Loss: 0.5080, Val CER: 0.1467 | Test CER: 0.2915
#
# Epoch 3/50
# [3/50] Train Loss: 0.7478, Train CER: 0.2100 | Val Loss: 0.4112, Val CER: 0.1112 | Test CER: 0.2315
#
# Epoch 4/50
# [4/50] Train Loss: 0.5926, Train CER: 0.1627 | Val Loss: 0.2935, Val CER: 0.0834 | Test CER: 0.1934
#
# Epoch 5/50
# [5/50] Train Loss: 0.4679, Train CER: 0.1282 | Val Loss: 0.3259, Val CER: 0.0905 | Test CER: 0.1874
#
# Epoch 6/50
# [6/50] Train Loss: 0.4063, Train CER: 0.1087 | Val Loss: 0.2556, Val CER: 0.0767 | Test CER: 0.1754
#
# Epoch 7/50
# [7/50] Train Loss: 0.3420, Train CER: 0.0896 | Val Loss: 0.2825, Val CER: 0.0806 | Test CER: 0.1824
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 8/50
# [8/50] Train Loss: 0.3084, Train CER: 0.0835 | Val Loss: 0.2598, Val CER: 0.0655 | Test CER: 0.1650
#
# Epoch 9/50
# [9/50] Train Loss: 0.2695, Train CER: 0.0729 | Val Loss: 0.2294, Val CER: 0.0610 | Test CER: 0.1532
#
# Epoch 10/50
# [10/50] Train Loss: 0.2181, Train CER: 0.0580 | Val Loss: 0.2601, Val CER: 0.0648 | Test CER: 0.1589
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 11/50
# [11/50] Train Loss: 0.2205, Train CER: 0.0578 | Val Loss: 0.3274, Val CER: 0.0884 | Test CER: 0.1777
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 12/50
# [12/50] Train Loss: 0.2088, Train CER: 0.0560 | Val Loss: 0.2738, Val CER: 0.0640 | Test CER: 0.1522
#
# Epoch 13/50
# [13/50] Train Loss: 0.1726, Train CER: 0.0459 | Val Loss: 0.2700, Val CER: 0.0644 | Test CER: 0.1491
#
# Epoch 14/50
# [14/50] Train Loss: 0.1500, Train CER: 0.0403 | Val Loss: 0.2731, Val CER: 0.0627 | Test CER: 0.1504
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 15/50
# [15/50] Train Loss: 0.1431, Train CER: 0.0378 | Val Loss: 0.2711, Val CER: 0.0622 | Test CER: 0.1552
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 16/50
# [16/50] Train Loss: 0.1327, Train CER: 0.0331 | Val Loss: 0.2657, Val CER: 0.0745 | Test CER: 0.1556
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 2h 8m.
#
# Results have been written to: training_results.csv
# hybrid_cnn_vit_encoder — Test CER: 0.1556
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 9.0000
#    Predicted       : panggaaar
#    Ground Truth    : .
#
# 2) Image: test8296.png
#    CER: 6.0000
#    Predicted       : dangdu
#    Ground Truth    : .
#
# 3) Image: test6297.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 4) Image: test9386.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 5) Image: test1335.png
#    CER: 4.0000
#    Predicted       : .anti
#    Ground Truth    : .
#
# Logged hybrid_cnn_vit_encoder: 0.1556
# Memory cleared for hybrid_cnn_vit_encoder

# %%
run_training_pipeline(
    encoder_class=SwinEncoder,
    encoder_kwargs={"model_name":"swin_small_patch4_window7_224","pretrained":True},
    model_name="swin_small_encoder",
    vocab_size=vocab_size,
    encoder_lr=1e-4,
    decoder_lr=4e-4,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    char_to_idx=char_to_idx,
    idx_to_char=idx_to_char,
    max_label_length=max_label_length,
    max_label_length_test=max_label_length_test,
    test_data=test_data,
    device=device)
# Out:
# Epoch 1/50
# [1/50] Train Loss: 2.2215, Train CER: 0.7600 | Val Loss: 1.7509, Val CER: 0.5237 | Test CER: 0.7002
#
# Epoch 2/50
# [2/50] Train Loss: 1.9631, Train CER: 0.5780 | Val Loss: 1.6357, Val CER: 0.4088 | Test CER: 0.6822
#
# Epoch 3/50
# [3/50] Train Loss: 1.8507, Train CER: 0.5281 | Val Loss: 1.5244, Val CER: 0.3832 | Test CER: 0.6519
#
# Epoch 4/50
# [4/50] Train Loss: 1.7116, Train CER: 0.4721 | Val Loss: 1.3238, Val CER: 0.3173 | Test CER: 0.5845
#
# Epoch 5/50
# [5/50] Train Loss: 1.6071, Train CER: 0.4326 | Val Loss: 1.2241, Val CER: 0.3112 | Test CER: 0.5416
#
# Epoch 6/50
# [6/50] Train Loss: 1.4802, Train CER: 0.3785 | Val Loss: 1.1037, Val CER: 0.2435 | Test CER: 0.5159
#
# Epoch 7/50
# [7/50] Train Loss: 1.3563, Train CER: 0.3434 | Val Loss: 0.9086, Val CER: 0.2141 | Test CER: 0.4668
#
# Epoch 8/50
# [8/50] Train Loss: 1.2334, Train CER: 0.3090 | Val Loss: 0.8122, Val CER: 0.1812 | Test CER: 0.4222
#
# Epoch 9/50
# [9/50] Train Loss: 1.1150, Train CER: 0.2757 | Val Loss: 0.7163, Val CER: 0.1930 | Test CER: 0.3836
#
# Epoch 10/50
# [10/50] Train Loss: 1.0025, Train CER: 0.2433 | Val Loss: 0.6251, Val CER: 0.1368 | Test CER: 0.3443
#
# Epoch 11/50
# [11/50] Train Loss: 0.8959, Train CER: 0.2164 | Val Loss: 0.5460, Val CER: 0.1260 | Test CER: 0.3245
#
# Epoch 12/50
# [12/50] Train Loss: 0.8131, Train CER: 0.1971 | Val Loss: 0.4734, Val CER: 0.0968 | Test CER: 0.2993
#
# Epoch 13/50
# [13/50] Train Loss: 0.7323, Train CER: 0.1749 | Val Loss: 0.4567, Val CER: 0.1049 | Test CER: 0.2887
#
# Epoch 14/50
# [14/50] Train Loss: 0.6642, Train CER: 0.1569 | Val Loss: 0.4326, Val CER: 0.0971 | Test CER: 0.2666
#
# Epoch 15/50
# [15/50] Train Loss: 0.6116, Train CER: 0.1430 | Val Loss: 0.3864, Val CER: 0.0875 | Test CER: 0.2475
#
# Epoch 16/50
# [16/50] Train Loss: 0.5594, Train CER: 0.1304 | Val Loss: 0.3279, Val CER: 0.0791 | Test CER: 0.2297
#
# Epoch 17/50
# [17/50] Train Loss: 0.5131, Train CER: 0.1212 | Val Loss: 0.3071, Val CER: 0.0769 | Test CER: 0.2273
#
# Epoch 18/50
# [18/50] Train Loss: 0.4560, Train CER: 0.1063 | Val Loss: 0.2778, Val CER: 0.0697 | Test CER: 0.2109
#
# Epoch 19/50
# [19/50] Train Loss: 0.4284, Train CER: 0.1007 | Val Loss: 0.2994, Val CER: 0.0724 | Test CER: 0.2121
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 20/50
# [20/50] Train Loss: 0.3992, Train CER: 0.0957 | Val Loss: 0.2899, Val CER: 0.0727 | Test CER: 0.1998
#
# Epoch 21/50
# [21/50] Train Loss: 0.3789, Train CER: 0.0899 | Val Loss: 0.2752, Val CER: 0.0594 | Test CER: 0.1940
#
# Epoch 22/50
# [22/50] Train Loss: 0.3462, Train CER: 0.0801 | Val Loss: 0.2632, Val CER: 0.0669 | Test CER: 0.1923
#
# Epoch 23/50
# [23/50] Train Loss: 0.3379, Train CER: 0.0792 | Val Loss: 0.2690, Val CER: 0.0637 | Test CER: 0.1872
#
# Epoch 24/50
# [24/50] Train Loss: 0.3045, Train CER: 0.0705 | Val Loss: 0.2362, Val CER: 0.0573 | Test CER: 0.1863
#
# Epoch 25/50
# [25/50] Train Loss: 0.2875, Train CER: 0.0664 | Val Loss: 0.2615, Val CER: 0.0564 | Test CER: 0.1803
#
# Epoch 26/50
# [26/50] Train Loss: 0.2649, Train CER: 0.0625 | Val Loss: 0.3170, Val CER: 0.0692 | Test CER: 0.1942
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 27/50
# [27/50] Train Loss: 0.2742, Train CER: 0.0640 | Val Loss: 0.2324, Val CER: 0.0567 | Test CER: 0.1770
#
# Epoch 28/50
# [28/50] Train Loss: 0.2413, Train CER: 0.0562 | Val Loss: 0.2387, Val CER: 0.0573 | Test CER: 0.1769
#
# Epoch 29/50
# [29/50] Train Loss: 0.2132, Train CER: 0.0506 | Val Loss: 0.2623, Val CER: 0.0620 | Test CER: 0.1765
#
# Epoch 30/50
# [30/50] Train Loss: 0.2145, Train CER: 0.0509 | Val Loss: 0.2414, Val CER: 0.0546 | Test CER: 0.1674
#
# Epoch 31/50
# [31/50] Train Loss: 0.2038, Train CER: 0.0472 | Val Loss: 0.2391, Val CER: 0.0560 | Test CER: 0.1709
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 32/50
# [32/50] Train Loss: 0.1855, Train CER: 0.0442 | Val Loss: 0.2435, Val CER: 0.0536 | Test CER: 0.1682
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 33/50
# [33/50] Train Loss: 0.1809, Train CER: 0.0416 | Val Loss: 0.2321, Val CER: 0.0519 | Test CER: 0.1656
#
# Epoch 34/50
# [34/50] Train Loss: 0.1742, Train CER: 0.0407 | Val Loss: 0.2672, Val CER: 0.0602 | Test CER: 0.1712
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 35/50
# [35/50] Train Loss: 0.1750, Train CER: 0.0398 | Val Loss: 0.2541, Val CER: 0.0520 | Test CER: 0.1665
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 36/50
# [36/50] Train Loss: 0.1533, Train CER: 0.0368 | Val Loss: 0.2650, Val CER: 0.0552 | Test CER: 0.1654
#
# Epoch 37/50
# [37/50] Train Loss: 0.1549, Train CER: 0.0370 | Val Loss: 0.2505, Val CER: 0.0590 | Test CER: 0.1710
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 38/50
# [38/50] Train Loss: 0.1614, Train CER: 0.0375 | Val Loss: 0.2462, Val CER: 0.0566 | Test CER: 0.1753
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 39/50
# [39/50] Train Loss: 0.1532, Train CER: 0.0359 | Val Loss: 0.2620, Val CER: 0.0590 | Test CER: 0.1617
#
# Epoch 40/50
# [40/50] Train Loss: 0.1380, Train CER: 0.0339 | Val Loss: 0.2390, Val CER: 0.0535 | Test CER: 0.1644
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 41/50
# [41/50] Train Loss: 0.1368, Train CER: 0.0318 | Val Loss: 0.2771, Val CER: 0.0577 | Test CER: 0.1687
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 42/50
# [42/50] Train Loss: 0.1515, Train CER: 0.0349 | Val Loss: 0.2640, Val CER: 0.0545 | Test CER: 0.1713
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 2h 21m.
#
# Results have been written to: training_results.csv
# swin_small_encoder — Test CER: 0.1713
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test3029.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 2) Image: test4934.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 3) Image: test7927.png
#    CER: 11.0000
#    Predicted       : crrik-agung
#    Ground Truth    : .
#
# 4) Image: test8296.png
#    CER: 8.0000
#    Predicted       : lurendel
#    Ground Truth    : .
#
# 5) Image: test580.png
#    CER: 7.0000
#    Predicted       : weranga
#    Ground Truth    : .
#
# Logged swin_small_encoder: 0.1713
# Memory cleared for swin_small_encoder

# %%
run_training_pipeline(
    encoder_class = SwinEncoder,
    encoder_kwargs= {"model_name": "swin_base_patch4_window7_224", "pretrained": True},
    model_name    = "swin_base_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 8e-5,    # lower LR for the larger Swin
    decoder_lr    = 3e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/50
# [1/50] Train Loss: 2.2452, Train CER: 0.7830 | Val Loss: 1.7737, Val CER: 0.4626 | Test CER: 0.7267
#
# Epoch 2/50
# [2/50] Train Loss: 1.9792, Train CER: 0.6007 | Val Loss: 1.6126, Val CER: 0.4545 | Test CER: 0.6595
#
# Epoch 3/50
# [3/50] Train Loss: 1.8608, Train CER: 0.5535 | Val Loss: 1.5096, Val CER: 0.4376 | Test CER: 0.6385
#
# Epoch 4/50
# [4/50] Train Loss: 1.7316, Train CER: 0.5001 | Val Loss: 1.3569, Val CER: 0.3792 | Test CER: 0.5856
#
# Epoch 5/50
# [5/50] Train Loss: 1.5885, Train CER: 0.4397 | Val Loss: 1.1820, Val CER: 0.3228 | Test CER: 0.5279
#
# Epoch 6/50
# [6/50] Train Loss: 1.4367, Train CER: 0.3828 | Val Loss: 1.0411, Val CER: 0.2424 | Test CER: 0.4995
#
# Epoch 7/50
# [7/50] Train Loss: 1.2958, Train CER: 0.3335 | Val Loss: 0.8689, Val CER: 0.1922 | Test CER: 0.4402
#
# Epoch 8/50
# [8/50] Train Loss: 1.1592, Train CER: 0.2947 | Val Loss: 0.7433, Val CER: 0.1894 | Test CER: 0.3947
#
# Epoch 9/50
# [9/50] Train Loss: 1.0141, Train CER: 0.2569 | Val Loss: 0.6424, Val CER: 0.1515 | Test CER: 0.3498
#
# Epoch 10/50
# [10/50] Train Loss: 0.8883, Train CER: 0.2221 | Val Loss: 0.5160, Val CER: 0.1331 | Test CER: 0.3124
#
# Epoch 11/50
# [11/50] Train Loss: 0.7929, Train CER: 0.1945 | Val Loss: 0.4893, Val CER: 0.1214 | Test CER: 0.2887
#
# Epoch 12/50
# [12/50] Train Loss: 0.7002, Train CER: 0.1717 | Val Loss: 0.4285, Val CER: 0.1050 | Test CER: 0.2623
#
# Epoch 13/50
# [13/50] Train Loss: 0.6263, Train CER: 0.1514 | Val Loss: 0.4155, Val CER: 0.0982 | Test CER: 0.2600
#
# Epoch 14/50
# [14/50] Train Loss: 0.5631, Train CER: 0.1384 | Val Loss: 0.3518, Val CER: 0.0861 | Test CER: 0.2365
#
# Epoch 15/50
# [15/50] Train Loss: 0.5087, Train CER: 0.1221 | Val Loss: 0.3139, Val CER: 0.0765 | Test CER: 0.2129
#
# Epoch 16/50
# [16/50] Train Loss: 0.4551, Train CER: 0.1100 | Val Loss: 0.3085, Val CER: 0.0822 | Test CER: 0.2151
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 17/50
# [17/50] Train Loss: 0.4193, Train CER: 0.1015 | Val Loss: 0.2957, Val CER: 0.0706 | Test CER: 0.2006
#
# Epoch 18/50
# [18/50] Train Loss: 0.3816, Train CER: 0.0908 | Val Loss: 0.3269, Val CER: 0.0819 | Test CER: 0.2177
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 19/50
# [19/50] Train Loss: 0.3558, Train CER: 0.0860 | Val Loss: 0.3134, Val CER: 0.0725 | Test CER: 0.1928
#
# Epoch 20/50
# [20/50] Train Loss: 0.3341, Train CER: 0.0806 | Val Loss: 0.2613, Val CER: 0.0624 | Test CER: 0.1899
#
# Epoch 21/50
# [21/50] Train Loss: 0.3151, Train CER: 0.0751 | Val Loss: 0.2701, Val CER: 0.0640 | Test CER: 0.1890
#
# Epoch 22/50
# [22/50] Train Loss: 0.2856, Train CER: 0.0680 | Val Loss: 0.2559, Val CER: 0.0613 | Test CER: 0.1912
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 23/50
# [23/50] Train Loss: 0.2668, Train CER: 0.0625 | Val Loss: 0.2885, Val CER: 0.0683 | Test CER: 0.1851
#
# Epoch 24/50
# [24/50] Train Loss: 0.2560, Train CER: 0.0627 | Val Loss: 0.2702, Val CER: 0.0631 | Test CER: 0.1831
#
# Epoch 25/50
# [25/50] Train Loss: 0.2477, Train CER: 0.0613 | Val Loss: 0.2600, Val CER: 0.0686 | Test CER: 0.1769
#
# Epoch 26/50
# [26/50] Train Loss: 0.2258, Train CER: 0.0526 | Val Loss: 0.2747, Val CER: 0.0576 | Test CER: 0.1750
#
# Epoch 27/50
# [27/50] Train Loss: 0.2061, Train CER: 0.0496 | Val Loss: 0.2681, Val CER: 0.0614 | Test CER: 0.1773
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 28/50
# [28/50] Train Loss: 0.1877, Train CER: 0.0446 | Val Loss: 0.2741, Val CER: 0.0620 | Test CER: 0.1728
#
# Epoch 29/50
# [29/50] Train Loss: 0.1826, Train CER: 0.0435 | Val Loss: 0.2597, Val CER: 0.0610 | Test CER: 0.1774
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 30/50
# [30/50] Train Loss: 0.1920, Train CER: 0.0440 | Val Loss: 0.2707, Val CER: 0.0637 | Test CER: 0.1786
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 31/50
# [31/50] Train Loss: 0.1868, Train CER: 0.0442 | Val Loss: 0.2750, Val CER: 0.0545 | Test CER: 0.1781
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 2h 23m.
#
# Results have been written to: training_results.csv
# swin_base_encoder — Test CER: 0.1781
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test3029.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 2) Image: test1330.png
#    CER: 10.0000
#    Predicted       : patulanaya
#    Ground Truth    : .
#
# 3) Image: test8296.png
#    CER: 8.0000
#    Predicted       : lianggut
#    Ground Truth    : .
#
# 4) Image: test5564.png
#    CER: 5.0000
#    Predicted       : taleng
#    Ground Truth    : e
#
# 5) Image: test6297.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# Logged swin_base_encoder: 0.1781
# Memory cleared for swin_base_encoder

# %%
run_training_pipeline(
    encoder_class = SwinEncoder,
    encoder_kwargs= {"model_name": "swin_large_patch4_window7_224", "pretrained": True},
    model_name    = "swin_large_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 5e-5,
    decoder_lr    = 2e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/50
# [1/50] Train Loss: 2.2711, Train CER: 0.7556 | Val Loss: 1.7478, Val CER: 0.4518 | Test CER: 0.7297
#
# Epoch 2/50
# [2/50] Train Loss: 1.9240, Train CER: 0.5806 | Val Loss: 1.5170, Val CER: 0.3954 | Test CER: 0.6421
#
# Epoch 3/50
# [3/50] Train Loss: 1.6907, Train CER: 0.4874 | Val Loss: 1.2525, Val CER: 0.3192 | Test CER: 0.5457
#
# Epoch 4/50
# [4/50] Train Loss: 1.4697, Train CER: 0.4035 | Val Loss: 1.0305, Val CER: 0.2572 | Test CER: 0.4738
#
# Epoch 5/50
# [5/50] Train Loss: 1.2985, Train CER: 0.3443 | Val Loss: 0.8787, Val CER: 0.2215 | Test CER: 0.4324
#
# Epoch 6/50
# [6/50] Train Loss: 1.1429, Train CER: 0.2932 | Val Loss: 0.7227, Val CER: 0.1702 | Test CER: 0.3889
#
# Epoch 7/50
# [7/50] Train Loss: 1.0192, Train CER: 0.2619 | Val Loss: 0.6077, Val CER: 0.1488 | Test CER: 0.3460
#
# Epoch 8/50
# [8/50] Train Loss: 0.8869, Train CER: 0.2206 | Val Loss: 0.5326, Val CER: 0.1281 | Test CER: 0.3093
#
# Epoch 9/50
# [9/50] Train Loss: 0.7981, Train CER: 0.1966 | Val Loss: 0.4888, Val CER: 0.1231 | Test CER: 0.3020
#
# Epoch 10/50
# [10/50] Train Loss: 0.7098, Train CER: 0.1731 | Val Loss: 0.4342, Val CER: 0.1067 | Test CER: 0.2626
#
# Epoch 11/50
# [11/50] Train Loss: 0.6220, Train CER: 0.1506 | Val Loss: 0.3977, Val CER: 0.0948 | Test CER: 0.2513
#
# Epoch 12/50
# [12/50] Train Loss: 0.5659, Train CER: 0.1361 | Val Loss: 0.3762, Val CER: 0.0892 | Test CER: 0.2361
#
# Epoch 13/50
# [13/50] Train Loss: 0.5195, Train CER: 0.1266 | Val Loss: 0.3557, Val CER: 0.0897 | Test CER: 0.2271
#
# Epoch 14/50
# [14/50] Train Loss: 0.4730, Train CER: 0.1113 | Val Loss: 0.3722, Val CER: 0.0920 | Test CER: 0.2236
#
# Epoch 15/50
# [15/50] Train Loss: 0.4324, Train CER: 0.1046 | Val Loss: 0.3326, Val CER: 0.0732 | Test CER: 0.2124
#
# Epoch 16/50
# [16/50] Train Loss: 0.3931, Train CER: 0.0951 | Val Loss: 0.3136, Val CER: 0.0709 | Test CER: 0.2103
#
# Epoch 17/50
# [17/50] Train Loss: 0.3599, Train CER: 0.0841 | Val Loss: 0.3158, Val CER: 0.0689 | Test CER: 0.2083
#
# Epoch 18/50
# [18/50] Train Loss: 0.3393, Train CER: 0.0803 | Val Loss: 0.3082, Val CER: 0.0681 | Test CER: 0.1977
#
# Epoch 19/50
# [19/50] Train Loss: 0.3161, Train CER: 0.0752 | Val Loss: 0.2971, Val CER: 0.0706 | Test CER: 0.2027
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 20/50
# [20/50] Train Loss: 0.2877, Train CER: 0.0690 | Val Loss: 0.3134, Val CER: 0.0689 | Test CER: 0.1886
#
# Epoch 21/50
# [21/50] Train Loss: 0.2762, Train CER: 0.0657 | Val Loss: 0.3154, Val CER: 0.0682 | Test CER: 0.1885
#
# Epoch 22/50
# [22/50] Train Loss: 0.2607, Train CER: 0.0621 | Val Loss: 0.2986, Val CER: 0.0683 | Test CER: 0.1825
#
# Epoch 23/50
# [23/50] Train Loss: 0.2462, Train CER: 0.0571 | Val Loss: 0.2976, Val CER: 0.0651 | Test CER: 0.1815
#
# Epoch 24/50
# [24/50] Train Loss: 0.2221, Train CER: 0.0518 | Val Loss: 0.3068, Val CER: 0.0608 | Test CER: 0.1797
#
# Epoch 25/50
# [25/50] Train Loss: 0.2009, Train CER: 0.0458 | Val Loss: 0.2766, Val CER: 0.0615 | Test CER: 0.1745
#
# Epoch 26/50
# [26/50] Train Loss: 0.2080, Train CER: 0.0489 | Val Loss: 0.2685, Val CER: 0.0606 | Test CER: 0.1781
# Test CER did not improve. Early stop counter: 1/3
#
# Epoch 27/50
# [27/50] Train Loss: 0.1926, Train CER: 0.0449 | Val Loss: 0.3020, Val CER: 0.0727 | Test CER: 0.1834
# Test CER did not improve. Early stop counter: 2/3
#
# Epoch 28/50
# [28/50] Train Loss: 0.1803, Train CER: 0.0423 | Val Loss: 0.3186, Val CER: 0.0660 | Test CER: 0.1798
# Test CER did not improve. Early stop counter: 3/3
# Early stopping triggered.
#
# Training completed in 3h 38m.
#
# Results have been written to: training_results.csv
# swin_large_encoder — Test CER: 0.1798
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 7.0000
#    Predicted       : saitata
#    Ground Truth    : .
#
# 2) Image: test580.png
#    CER: 6.0000
#    Predicted       : siatia
#    Ground Truth    : .
#
# 3) Image: test9386.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 4) Image: test1770.png
#    CER: 4.0000
#    Predicted       : iiing
#    Ground Truth    : i
#
# 5) Image: test6559.png
#    CER: 4.0000
#    Predicted       : giing
#    Ground Truth    : i
#
# Logged swin_large_encoder: 0.1798
# Memory cleared for swin_large_encoder
