# %%
import os
import pandas as pd
import numpy as np
import editdistance
import time 
import random

from PIL import Image
from collections import Counter

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.models as models
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import torch.nn.functional as F
from torchvision import transforms

import timm  
from sklearn.model_selection import train_test_split

# %%
from augmentations.script_level.Information_extraction import information_extraction
from augmentations.script_level.transformation import flag_judge, identify_reference_corner
from augmentations.script_level.transformation import bezier_transformation, affine_transformation, L2A_transformation
from augmentations.script_level import script_aug
from augmentations.script_level.script_aug import new_local

# %%
# import  sys
# # sys.path.insert(0, '/fs04/qb36/lontar_project/code/gru_aug')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Base project path
BASE_DIR = "/projects/qb36/lontar_project"
DATA_DIR = os.path.join(BASE_DIR, "data")

# Define file paths
ground_truth_path = os.path.join(DATA_DIR, 'balinese_transliteration_train.txt')
images_dir = os.path.join(DATA_DIR, 'balinese_word_train')

# %%
# base_dir = os.getcwd()

# # Same paths as your original code
# ground_truth_path = os.path.join(base_dir, 'balinese_transliteration_train.txt') 
# images_dir        = os.path.join(base_dir, 'balinese_word_train')


filenames = []
labels    = []

with open(ground_truth_path, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        if line:  # Ensure the line is not empty
            parts = line.split(';')
            if len(parts) == 2:
                filename, label = parts
                label = label.lower()
                filenames.append(filename)
                labels.append(label)
            else:
                print(f"Skipping malformed line: {line}")

data = pd.DataFrame({
    'filename': filenames,
    'label': labels
})

label_counts = data['label'].value_counts()

all_text = ''.join(data['label'])
unique_chars = sorted(list(set(all_text)))

# Create character->index starting from 1
char_to_idx = {char: idx + 1 for idx, char in enumerate(unique_chars)}
# Add special tokens
char_to_idx['<PAD>'] = 0
char_to_idx['<UNK>'] = len(char_to_idx)
char_to_idx['<SOS>'] = len(char_to_idx)
char_to_idx['<EOS>'] = len(char_to_idx)

# Reverse mapping
idx_to_char = {v: k for k, v in char_to_idx.items()}

vocab_size = len(char_to_idx)
print(f"Vocabulary size: {vocab_size}")

def encode_label(label, char_to_idx, max_length):
    """
    Converts a label (string) into a list of indices with <SOS>, <EOS>, padding, etc.
    """
    encoded = (
        [char_to_idx['<SOS>']] +
        [char_to_idx.get(ch, char_to_idx['<UNK>']) for ch in label] +
        [char_to_idx['<EOS>']]
    )
    # Pad if needed
    if len(encoded) < max_length:
        encoded += [char_to_idx['<PAD>']] * (max_length - len(encoded))
    else:
        encoded = encoded[:max_length]
    return encoded

max_label_length = max(len(label) for label in data['label']) + 2  # +2 for <SOS> and <EOS>
data['encoded_label'] = data['label'].apply(lambda x: encode_label(x, char_to_idx, max_label_length))
data['label_length']  = data['label'].apply(len)

rare_labels = label_counts[label_counts < 3].index  # NEW: words that appear <3 times

def custom_split(df, rare_label_list, test_size=0.1, random_state=42):
    # Separate rare words from frequent ones
    rare_df     = df[df['label'].isin(rare_label_list)]
    non_rare_df = df[~df['label'].isin(rare_label_list)]

    #  train/val split for non-rare
    train_nr, val_nr = train_test_split(non_rare_df, test_size=test_size, 
                                        random_state=random_state)

    # Combine rare samples entirely into training
    train_df = pd.concat([train_nr, rare_df], ignore_index=True)
    # Shuffle after combining
    train_df = train_df.sample(frac=1, random_state=random_state).reset_index(drop=True)

    val_df = val_nr.reset_index(drop=True)
    return train_df, val_df

# Call custom_split instead of direct train_test_split
train_data, val_data = custom_split(data, rare_labels, test_size=0.1, random_state=42) 

print(f"Training size: {len(train_data)}; Validation size: {len(val_data)}")
# Out:
# Vocabulary size: 39
# Training size: 13972; Validation size: 1050

# %%
class BalineseDataset(Dataset):
    def __init__(self, df, images_dir, transform=None):
        self.data       = df.reset_index(drop=True)
        self.images_dir = images_dir
        self.transform  = transform

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_name     = self.data.loc[idx, 'filename']
        label        = self.data.loc[idx, 'encoded_label']
        label_length = self.data.loc[idx, 'label_length']

        img_path = os.path.join(self.images_dir, img_name)
        image    = Image.open(img_path).convert('RGB')

        if self.transform:
            image = self.transform(image)

        label = torch.tensor(label, dtype=torch.long)
        return image, label, torch.tensor(label_length, dtype=torch.long)

# %%
class ScriptLevelAugment:
    """
    Wraps the ICFHR'22 script-level augmentation as a torchvision-style transform.
    Only applies augmentation with probability `prob`.
    """
    def __init__(self, 
                 prob=0.5,
                 stroke_radius=2,
                 k1_control_field_corner=0.6,
                 k2_control_field_third_bezier=0.6,
                 segment=2):
        self.prob = prob
        self.stroke_radius = stroke_radius
        self.k1_control_field_corner = k1_control_field_corner
        self.k2_control_field_third_bezier = k2_control_field_third_bezier
        self.segment = segment

    def __call__(self, pil_img):
        if random.random() > self.prob:
            return pil_img
        # Convert PIL Image to numpy array (RGB)
        img = np.array(pil_img.convert("RGB"))
        # Run augmentation (get list of augmented images, pick the first)
        aug_imgs = new_local(
            img, 
            times=1,
            stroke_radius=self.stroke_radius,
            k1_control_field_corner=self.k1_control_field_corner,
            k2_control_field_third_bezier=self.k2_control_field_third_bezier,
            segment=self.segment
        )
        # Defensive: fallback if augmentation fails
        if not aug_imgs or not isinstance(aug_imgs[0], np.ndarray):
            return pil_img
        # Convert back to PIL Image
        aug_pil = Image.fromarray(aug_imgs[0].astype(np.uint8)).convert("RGB")
        return aug_pil

# %%
# train_transform = transforms.Compose([
#     transforms.Resize((224, 224)),
#     transforms.RandomRotation(degrees=5),
#     transforms.RandomAffine(degrees=0, translate=(0.05, 0.05)),
#     transforms.ColorJitter(brightness=0.2, contrast=0.2),
#     transforms.ToTensor(),
#     transforms.RandomErasing(p=0.5, scale=(0.01, 0.05), ratio=(0.3, 3.3)),
#     transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
# ])


train_transform = transforms.Compose([
    ScriptLevelAugment(prob=0.3),  # 30% chance augment
    transforms.Resize((224, 224)),
    transforms.RandomRotation(degrees=5),
    transforms.RandomAffine(degrees=0, translate=(0.05, 0.05)),
    transforms.ColorJitter(brightness=0.2, contrast=0.2),
    transforms.ToTensor(),
    transforms.RandomErasing(p=0.5, scale=(0.01, 0.05), ratio=(0.3, 3.3)),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])


val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5)),
])

train_dataset = BalineseDataset(train_data, images_dir, transform=train_transform)
val_dataset   = BalineseDataset(val_data,   images_dir, transform=val_transform)

batch_size = 32

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=batch_size, shuffle=False, num_workers=2, pin_memory=True)

# %%
class ResNet18Encoder(nn.Module):
    """
    Encoder that uses a pretrained ResNet18 to extract features of shape 
    [B, H*W, C], which the DecoderRNN can then attend over.
    """

    def __init__(self, pretrained=True):
        super(ResNet18Encoder, self).__init__()
        resnet = models.resnet18(pretrained=pretrained)

        # Remove the classification (fc) layer
        modules = list(resnet.children())[:-2]  # remove the avgpool & fc
        self.cnn = nn.Sequential(*modules)

        # last convolutional block outputs 512 channels
        self.encoder_dim = 512

    def forward(self, x):
        """
        Input shape:  x -> [batch_size, 3, 224, 224]
        Output shape: -> [batch_size, num_patches, encoder_dim]
                       where num_patches = H' * W' from the final feature map
        """
        # pass through ResNet (up to layer4)
        features = self.cnn(x)  # [B, 512, H', W']

        # Flatten the spatial dims
        # shape => [B, 512, H', W'] -> [B, H'*W', 512]
        b, c, h, w = features.shape
        features = features.permute(0, 2, 3, 1)   # [B, H', W', C]
        features = features.reshape(b, -1, c)     # [B, H'*W', C]

        return features

# %%
class ViTEncoder(nn.Module):
    """
    A simple ViT encoder that extracts patch embeddings as [batch_size, num_patches, hidden_dim].
    We'll use timm to load a pretrained ViT. Then we use .forward_features() to get a
    feature map of shape [B, C, H', W'] for many timm ViT models, which we flatten.
    """
    def __init__(self, model_name, pretrained=True):
        super(ViTEncoder, self).__init__()
        self.vit = timm.create_model(model_name, pretrained=pretrained)
        # Remove or replace the classification head
        self.vit.head = nn.Identity()

        # timm's ViT typically has an embed_dim attribute
        self.encoder_dim = self.vit.embed_dim

    def forward(self, x):
        """
        :param x: [batch_size, 3, 224, 224]
        :return:  [batch_size, num_patches, encoder_dim]
        """
        # forward_features usually returns [B, hidden_dim, H', W'] or [B, hidden_dim]
        feats = self.vit.forward_features(x)  # [B, hidden_dim, 14, 14] for vit_base_patch16_224

        # Flatten the spatial dimensions
        if feats.dim() == 4:  # [B, C, H, W]
            b, c, h, w = feats.shape
            feats = feats.permute(0, 2, 3, 1).reshape(b, -1, c)  # => [B, H*W, C]

        return feats

# %%
class SwinEncoder(nn.Module):
    def __init__(self, model_name="swin_small_patch4_window7_224", pretrained=True):
        """
        A simple Swin Transformer encoder that extracts patch embeddings
        as [batch_size, num_patches, hidden_dim]. We'll use timm to load 
        a pretrained Swin model, remove its classification head, then flatten.
        """
        super().__init__()
        self.swin = timm.create_model(model_name, pretrained=pretrained)
        self.swin.head = nn.Identity()

        # We'll assign encoder_dim dynamically after forward
        self.encoder_dim = None

    def forward(self, x):
        """
        :param x: [batch_size, 3, 224, 224]
        :return:  [batch_size, num_patches, encoder_dim]
        """
        feats = self.swin.forward_features(x)            # [B, C, H, W]
        b, c, h, w = feats.shape
        feats = feats.flatten(2).transpose(1, 2)         # [B, H*W, C]
        # Set encoder_dim once (C)
        if self.encoder_dim is None:
            self.encoder_dim = feats.shape[-1]
        return feats

# %%
class HybridEncoder(nn.Module):
    def __init__(self, cnn_encoder, vit_encoder):
        super(HybridEncoder, self).__init__()
        self.cnn_encoder = cnn_encoder
        self.vit_encoder = vit_encoder
        # Combined encoder_dim is the sum of both encoder dimensions.
        # (CNN outputs 512 channels; ViT outputs its own embed_dim.)
        self.encoder_dim = cnn_encoder.encoder_dim + vit_encoder.encoder_dim

    def forward(self, x):
        # Get CNN features: expected shape [B, 49, 512]
        cnn_features = self.cnn_encoder(x)

        # Get ViT features: expected shape [B, 197, vit_dim] for vit_large_patch16_224
        vit_features = self.vit_encoder(x)
        # If the ViT output contains a class token, remove it.
        if vit_features.shape[1] == 197:
            vit_features = vit_features[:, 1:, :]  # Now shape: [B, 196, vit_dim]
            B, tokens, D = vit_features.shape
            # Reshape tokens into a 14x14 grid: [B, 14, 14, D]
            vit_features = vit_features.reshape(B, 14, 14, D)
            # Permute to [B, D, 14, 14] for pooling
            vit_features = vit_features.permute(0, 3, 1, 2)
            # Use adaptive pooling to reduce to a 7x7 grid
            vit_features = F.adaptive_avg_pool2d(vit_features, (7, 7))
            # Permute back to [B, 7, 7, D] and flatten to [B, 49, D]
            vit_features = vit_features.permute(0, 2, 3, 1).reshape(B, -1, D)

        # Concatenate the features along the feature dimension (dim=2)
        # cnn_features: [B, 49, 512] and vit_features: [B, 49, vit_dim]
        hybrid_features = torch.cat([cnn_features, vit_features], dim=2)
        return hybrid_features

# %%
class Attention(nn.Module):
    def __init__(self, encoder_dim, decoder_dim, attention_dim):
        super(Attention, self).__init__()
        self.encoder_att = nn.Linear(encoder_dim, attention_dim)  # transform encoder output
        self.decoder_att = nn.Linear(decoder_dim, attention_dim)  # transform decoder hidden
        self.full_att    = nn.Linear(attention_dim, 1)
        self.relu        = nn.ReLU()
        self.softmax     = nn.Softmax(dim=1)

    def forward(self, encoder_out, decoder_hidden):
        """
        encoder_out:    [batch_size, num_patches, encoder_dim]
        decoder_hidden: [batch_size, decoder_dim]
        """
        att1 = self.encoder_att(encoder_out)                  # [batch_size, num_patches, attention_dim]
        att2 = self.decoder_att(decoder_hidden).unsqueeze(1)  # [batch_size, 1, attention_dim]

        # sum -> relu -> full_att -> squeeze -> softmax
        att  = self.full_att(self.relu(att1 + att2)).squeeze(2)  # [batch_size, num_patches]
        alpha = self.softmax(att)
        # Weighted sum of the encoder_out
        attention_weighted_encoding = (encoder_out * alpha.unsqueeze(2)).sum(dim=1)  # [batch_size, encoder_dim]
        return attention_weighted_encoding, alpha

# %%
class DecoderRNN(nn.Module):
    def __init__(self, attention_dim, embed_dim, decoder_dim, vocab_size, encoder_dim=768, teacher_forcing_ratio=0.5):
        super(DecoderRNN, self).__init__()

        self.attention     = Attention(encoder_dim, decoder_dim, attention_dim)
        self.embedding     = nn.Embedding(vocab_size, embed_dim)
        self.dropout       = nn.Dropout(p=0.5)

        # [embed_dim + encoder_dim] -> decoder_dim
        self.lstm1 = nn.LSTMCell(embed_dim + encoder_dim, decoder_dim)
        # decoder_dim -> decoder_dim
        self.lstm2 = nn.LSTMCell(decoder_dim, decoder_dim)

        # For initializing the hidden states of both LSTM layers
        self.init_h1 = nn.Linear(encoder_dim, decoder_dim)
        self.init_c1 = nn.Linear(encoder_dim, decoder_dim)
        self.init_h2 = nn.Linear(encoder_dim, decoder_dim)
        self.init_c2 = nn.Linear(encoder_dim, decoder_dim)

        # Gating
        self.f_beta  = nn.Linear(decoder_dim, encoder_dim)
        self.sigmoid = nn.Sigmoid()

        # Final linear layer for output vocab
        self.fc = nn.Linear(decoder_dim, vocab_size)

        self.teacher_forcing_ratio = teacher_forcing_ratio

        self.init_weights()

    def init_weights(self):
        self.embedding.weight.data.uniform_(-0.1, 0.1)
        self.fc.bias.data.fill_(0)
        self.fc.weight.data.uniform_(-0.1, 0.1)

    def init_hidden_state(self, encoder_out):
        # encoder_out: [batch_size, num_patches, encoder_dim]
        mean_encoder_out = encoder_out.mean(dim=1)  # [batch_size, encoder_dim]
        h1 = self.init_h1(mean_encoder_out)         # [batch_size, decoder_dim]
        c1 = self.init_c1(mean_encoder_out)         # [batch_size, decoder_dim]
        h2 = self.init_h2(mean_encoder_out)         # [batch_size, decoder_dim]
        c2 = self.init_c2(mean_encoder_out)         # [batch_size, decoder_dim]
        return (h1, c1, h2, c2)


    def forward(self, encoder_out, encoded_captions, caption_lengths):
        """
        encoder_out:      [batch_size, num_patches, encoder_dim]
        encoded_captions: [batch_size, max_label_length]
        caption_lengths:  [batch_size, 1]
        """
        caption_lengths, sort_ind = caption_lengths.squeeze(1).sort(dim=0, descending=True)
        encoder_out      = encoder_out[sort_ind]
        encoded_captions = encoded_captions[sort_ind]

        embeddings = self.embedding(encoded_captions)

        # Initialize hidden states for both LSTM layers
        h1, c1, h2, c2 = self.init_hidden_state(encoder_out)

        decode_lengths    = (caption_lengths - 1).tolist()
        max_decode_length = max(decode_lengths)

        batch_size = encoder_out.size(0)
        vocab_size = self.fc.out_features

        predictions = torch.zeros(batch_size, max_decode_length, vocab_size, device=encoder_out.device)
        alphas      = torch.zeros(batch_size, max_decode_length, encoder_out.size(1), device=encoder_out.device)

        # We'll feed the first token from the input (<SOS>) or from the previous prediction
        prev_tokens = encoded_captions[:, 0].clone()

        for t in range(max_decode_length):
            batch_size_t = sum([l > t for l in decode_lengths])

            attention_weighted_encoding, alpha = self.attention(
                encoder_out[:batch_size_t],
                h1[:batch_size_t]  # use the first LSTM layer's hidden state for attention
            )

            # Apply gating
            gate = self.sigmoid(self.f_beta(h1[:batch_size_t]))
            attention_weighted_encoding = gate * attention_weighted_encoding

            # Teacher forcing?
            use_teacher_forcing = (torch.rand(1).item() < self.teacher_forcing_ratio)
            if use_teacher_forcing:
                current_input = embeddings[:batch_size_t, t, :]
            else:
                current_input = self.embedding(prev_tokens[:batch_size_t].detach())

            # first lstm layer
            h1_next, c1_next = self.lstm1(
                torch.cat([current_input, attention_weighted_encoding], dim=1),
                (h1[:batch_size_t], c1[:batch_size_t])
            )

            # second lstm layer
            h2_next, c2_next = self.lstm2(
                h1_next, (h2[:batch_size_t], c2[:batch_size_t])
            )

            # Use the second LSTM layer's output (h2_next) for final prediction
            preds = self.fc(self.dropout(h2_next))
            predictions[:batch_size_t, t, :] = preds
            alphas[:batch_size_t, t, :]      = alpha

            # Update prev_tokens with the best predicted token
            _, next_tokens = preds.max(dim=1)
            prev_tokens_ = prev_tokens.clone()
            prev_tokens_[:batch_size_t] = next_tokens.detach()
            prev_tokens = prev_tokens_

            # Update hidden states
            # For samples still in the batch, store the new h1, c1, h2, c2
            h1_new = torch.zeros_like(h1)
            c1_new = torch.zeros_like(c1)
            h2_new = torch.zeros_like(h2)
            c2_new = torch.zeros_like(c2)

            h1_new[:batch_size_t] = h1_next
            c1_new[:batch_size_t] = c1_next
            h2_new[:batch_size_t] = h2_next
            c2_new[:batch_size_t] = c2_next

            h1, c1, h2, c2 = h1_new, c1_new, h2_new, c2_new

        return predictions, encoded_captions, decode_lengths, alphas, sort_ind

# %%
class ImageCaptioningTrainer:
    def __init__(self, encoder, decoder, 
                 criterion, encoder_optimizer, decoder_optimizer, 
                 train_loader, val_loader, test_loader, test_data, max_label_length_test,
                 device, char_to_idx, idx_to_char, max_label_length,
                 model_name, csv_filename="training_results.csv"):
        self.encoder = encoder.to(device)
        self.decoder = decoder.to(device)
        self.criterion = criterion
        self.encoder_optimizer = encoder_optimizer
        self.decoder_optimizer = decoder_optimizer
        self.train_loader = train_loader
        self.val_loader = val_loader
        self.test_loader = test_loader
        self.test_data = test_data
        self.max_label_length_test = max_label_length_test
        self.device = device
        self.char_to_idx = char_to_idx
        self.idx_to_char = idx_to_char
        self.max_label_length = max_label_length
        self.model_name = model_name
        self.csv_filename = csv_filename

        self.train_losses = []
        self.val_losses = []
        self.train_cers = []
        self.val_cers = []
        self.test_cers = []

    def fit(self, num_epochs):
        start_time = time.time()
        
        # Early stopping parameters
        best_val_loss = float('inf')
        early_stop_counter = 0
        early_stop_patience = 10

        for epoch in range(num_epochs):
            print(f"\nEpoch {epoch + 1}/{num_epochs}")
            train_loss, train_cer = self.train_one_epoch()
            val_loss, val_cer = self.validate_one_epoch(top_n=5)

            print(f"[{epoch+1}/{num_epochs}] "
                  f"Train Loss: {train_loss:.4f}, Train CER: {train_cer:.4f} | "
                  f"Val Loss: {val_loss:.4f}, Val CER: {val_cer:.4f}")

            # Store epoch results
            self.train_losses.append(train_loss)
            self.val_losses.append(val_loss)
            self.train_cers.append(train_cer)
            self.val_cers.append(val_cer)
            
            # Early stopping check: if current val_loss is better, reset counter; otherwise, increment.
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                early_stop_counter = 0
            else:
                early_stop_counter += 1
                print(f"Validation loss did not improve. Early stop counter: {early_stop_counter}/{early_stop_patience}")
            
            if early_stop_counter >= early_stop_patience:
                print("Early stopping triggered.")
                break
        
        # Calculate total training time
        end_time = time.time() 
        total_time = end_time - start_time
        hours = int(total_time // 3600)
        minutes = int((total_time % 3600) // 60)

        print(f"\nTraining completed in {hours}h {minutes}m.")

        num_epochs_recorded = len(self.train_losses)
        epoch_cols = [f"epoch{i+1}" for i in range(num_epochs_recorded)]

        # Create the new data block to insert
        new_rows = pd.DataFrame([
            [self.model_name, "training loss"] + self.train_losses,
            [self.model_name, "validation loss"] + self.val_losses,
            [self.model_name, "training cer"] + self.train_cers,
            [self.model_name, "validation cer"] + self.val_cers
        ], columns=["model_name", "mode"] + epoch_cols)
        
        # Check if CSV already exists
        if os.path.exists(self.csv_filename):
            df_existing = pd.read_csv(self.csv_filename)
            df_existing = df_existing[df_existing["model_name"] != self.model_name]
            df_updated = pd.concat([df_existing, new_rows], ignore_index=True)
        else:
            df_updated = new_rows

        df_updated[epoch_cols] = np.floor(df_updated[epoch_cols] * 100) / 100 
        
        # Save the updated CSV
        df_updated.to_csv(self.csv_filename, index=False)
        print(f"\nResults have been written to: {self.csv_filename}")

        # Save model weights
        # torch.save(self.encoder.state_dict(), f"encoder_{self.model_name}.pth")
        # torch.save(self.decoder.state_dict(), f"decoder_{self.model_name}.pth")
        # print(f"Encoder and decoder models saved: encoder_{self.model_name}.pth, decoder_{self.model_name}.pth")

    def train_one_epoch(self):
        self.encoder.train()
        self.decoder.train()
        running_loss           = 0.0
        total_edit_distance    = 0
        total_ref_length       = 0

        for batch_idx, (images, labels, label_lengths) in enumerate(self.train_loader):
            images        = images.to(self.device, non_blocking=True)
            labels        = labels.to(self.device, non_blocking=True)
            label_lengths = label_lengths.to(self.device, non_blocking=True)

            self.encoder_optimizer.zero_grad()
            self.decoder_optimizer.zero_grad()

            encoder_out   = self.encoder(images)
            caption_lengths = torch.tensor(
                [self.max_label_length] * labels.size(0)
            ).unsqueeze(1).to(self.device)

            outputs, encoded_captions, decode_lengths, alphas, sort_ind = self.decoder(
                encoder_out, labels, caption_lengths
            )

            # Targets = encoded captions without the <SOS>
            targets = encoded_captions[:, 1:]

            # Flatten for loss
            outputs_flat = outputs.view(-1, self.decoder.fc.out_features)
            targets_flat = targets.contiguous().view(-1)

            loss = self.criterion(outputs_flat, targets_flat)
            loss.backward()

            self.decoder_optimizer.step()
            self.encoder_optimizer.step()

            running_loss += loss.item()

            # Compute CER for the batch (global style)
            batch_size = labels.size(0)
            _, preds_flat = torch.max(outputs_flat, dim=1)
            preds_seq = preds_flat.view(batch_size, -1)

            for i in range(batch_size):
                pred_indices   = preds_seq[i].detach().cpu().numpy()
                target_indices = targets[i].detach().cpu().numpy()

                mask          = (target_indices != self.char_to_idx['<PAD>'])
                pred_indices  = pred_indices[mask]
                target_indices= target_indices[mask]

                pred_chars    = [self.idx_to_char.get(idx, '') for idx in pred_indices]
                target_chars  = [self.idx_to_char.get(idx, '') for idx in target_indices]
                pred_str      = ''.join(pred_chars)
                target_str    = ''.join(target_chars)

                edit_dist           = editdistance.eval(pred_str, target_str)
                total_edit_distance += edit_dist
                total_ref_length    += len(target_str)

            # if (batch_idx + 1) % 50 == 0:
            #     print(f'Batch {batch_idx + 1}/{len(self.train_loader)} - Loss: {loss.item():.4f}')

        avg_loss = running_loss / len(self.train_loader)
        avg_cer  = total_edit_distance / total_ref_length if total_ref_length > 0 else 0.0
        return avg_loss, avg_cer

    def validate_one_epoch(self, top_n=5):
        self.encoder.eval()
        self.decoder.eval()
        running_loss         = 0.0
        total_edit_distance  = 0
        total_ref_length     = 0

        # each sample’s CER
        sample_cer_info = []

        with torch.no_grad():
            for batch_idx, (images, labels, label_lengths) in enumerate(self.val_loader):
                images        = images.to(self.device, non_blocking=True)
                labels        = labels.to(self.device, non_blocking=True)
                label_lengths = label_lengths.to(self.device, non_blocking=True)

                encoder_out = self.encoder(images)
                caption_lengths = torch.tensor(
                    [self.max_label_length] * labels.size(0)
                ).unsqueeze(1).to(self.device)

                outputs, encoded_captions, decode_lengths, alphas, sort_ind = self.decoder(
                    encoder_out, labels, caption_lengths
                )
                targets = encoded_captions[:, 1:]

                outputs_flat = outputs.view(-1, self.decoder.fc.out_features)
                targets_flat = targets.contiguous().view(-1)

                loss = self.criterion(outputs_flat, targets_flat)
                running_loss += loss.item()

                batch_size = labels.size(0)
                _, preds_flat = torch.max(outputs_flat, dim=1)
                preds_seq = preds_flat.view(batch_size, -1)

                for i in range(batch_size):
                    pred_indices   = preds_seq[i].detach().cpu().numpy()
                    target_indices = targets[i].detach().cpu().numpy()

                    mask           = (target_indices != self.char_to_idx['<PAD>'])
                    pred_indices   = pred_indices[mask]
                    target_indices = target_indices[mask]

                    pred_chars   = [self.idx_to_char.get(idx, '') for idx in pred_indices]
                    target_chars = [self.idx_to_char.get(idx, '') for idx in target_indices]
                    pred_str     = ''.join(pred_chars)
                    target_str   = ''.join(target_chars)

                    edit_dist = editdistance.eval(pred_str, target_str)
                    ref_len   = len(target_str)
                    cer       = edit_dist / ref_len if ref_len > 0 else 0
    
                    total_edit_distance += edit_dist
                    total_ref_length    += ref_len
    
                    # Store sample info
                    # sample_cer_info.append({
                    #     "pred": pred_str,
                    #     "gt": target_str,
                    #     "cer": cer
                    # })

                    # Print a few samples from the 1st batch
                    # if batch_idx == 0 and i < 3:
                    #     print(f"Sample {i + 1}:")
                    #     print(f"Predicted: {pred_str}")
                    #     print(f"Target   : {target_str}\n")

        avg_loss = running_loss / len(self.val_loader)
        avg_cer  = total_edit_distance / total_ref_length if total_ref_length > 0 else 0.0

        # Sort by CER descending
        sample_cer_info.sort(key=lambda x: x["cer"], reverse=True)
        # Take top_n
        worst_samples = sample_cer_info[:top_n]
    
        # print(f"\n=== Top {top_n} Worst Samples by CER ===")
        # for idx, sample in enumerate(worst_samples):
        #     print(f"[{idx+1}] CER: {sample['cer']:.3f}")
        #     print(f"   Predicted: {sample['pred']}")
        #     print(f"   Ground Truth: {sample['gt']}\n")
       
        return avg_loss, avg_cer

# %%
test_ground_truth_path = os.path.join(DATA_DIR, 'balinese_transliteration_test.txt')
test_images_dir        = os.path.join(DATA_DIR, 'balinese_word_test')

test_filenames = []
test_labels    = []

with open(test_ground_truth_path, 'r', encoding='utf-8') as file:
    for line in file:
        line = line.strip()
        if line:
            parts = line.split(';')
            if len(parts) == 2:
                filename, label = parts
                label = label.lower()
                test_filenames.append(filename)
                test_labels.append(label)
            else:
                print(f"Skipping malformed line: {line}")

test_data = pd.DataFrame({
    'filename': test_filenames,
    'label': test_labels
})

# Check for unknown chars in test set
test_chars = set(''.join(test_data['label']))
unknown_chars = test_chars - set(char_to_idx.keys())
print(f"Unknown characters in test labels: {unknown_chars}")

# Encode test labels
max_label_length_test = max(len(lbl) for lbl in test_data['label']) + 2
def encode_label_test(label, char_to_idx, max_length):
    encoded = (
        [char_to_idx['<SOS>']] +
        [char_to_idx.get(ch, char_to_idx['<UNK>']) for ch in label] +
        [char_to_idx['<EOS>']]
    )
    if len(encoded) > max_length:
        encoded = encoded[:max_length]
    else:
        encoded += [char_to_idx['<PAD>']] * (max_length - len(encoded))
    return encoded

test_data['encoded_label'] = test_data['label'].apply(lambda x: encode_label_test(x, char_to_idx, max_label_length_test))
test_data['label_length']  = test_data['label'].apply(len)

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=(0.5, 0.5, 0.5),
        std=(0.5, 0.5, 0.5)
    )
])

test_dataset = BalineseDataset(test_data, test_images_dir, transform=test_transform)
test_loader  = DataLoader(test_dataset, batch_size=32, shuffle=False, num_workers=0)
# Out:
# Unknown characters in test labels: set()

# %%
def inference(encoder, decoder, data_loader, device, char_to_idx, idx_to_char, max_seq_length, test_data):
    encoder.eval()
    decoder.eval()

    eos_idx = char_to_idx['<EOS>']
    results = []

    with torch.no_grad():
        for batch_idx, (images, labels, label_lengths) in enumerate(data_loader):
            images = images.to(device, non_blocking=True)
            labels = labels.to(device, non_blocking=True)

            batch_size  = images.size(0)
            encoder_out = encoder(images)  # [B, num_patches, encoder_dim]

            # Init LSTM state
            h1, c1, h2, c2 = decoder.init_hidden_state(encoder_out)

            # Start tokens (all <SOS>)
            inputs = torch.full(
                (batch_size,),
                fill_value=char_to_idx['<SOS>'],
                dtype=torch.long,
                device=device
            )

            all_preds = []

            for _ in range(max_seq_length):
                # Embedding
                embeddings = decoder.embedding(inputs)

                # Attention
                attention_weighted_encoding, _ = decoder.attention(encoder_out, h1)

                # Gating
                gate = decoder.sigmoid(decoder.f_beta(h1))
                attention_weighted_encoding = gate * attention_weighted_encoding

                # Pass through LSTM layers
                h1, c1 = decoder.lstm1(
                    torch.cat([embeddings, attention_weighted_encoding], dim=1),
                    (h1, c1)
                )
                h2, c2 = decoder.lstm2(h1, (h2, c2))

                # Get predicted token
                preds = decoder.fc(decoder.dropout(h2))  # [batch_size, vocab_size]
                _, preds_idx = preds.max(dim=1)

                # Feed next token
                all_preds.append(preds_idx.cpu().numpy())
                inputs = preds_idx

            # Reformat predictions to [batch_size, max_seq_length]
            all_preds = np.array(all_preds).T

            for i in range(batch_size):
                pred_indices = all_preds[i]

                # Stop at <EOS> if present
                if eos_idx in pred_indices:
                    first_eos = np.where(pred_indices == eos_idx)[0][0]
                    pred_indices = pred_indices[:first_eos]

                # Convert token indices -> string
                pred_chars = [idx_to_char.get(idx, '') for idx in pred_indices]
                pred_str   = ''.join(pred_chars)

                # Process ground truth
                label_indices = labels[i].cpu().numpy()
                # remove <SOS>
                label_indices = label_indices[1:]

                if eos_idx in label_indices:
                    eos_pos = np.where(label_indices == eos_idx)[0][0]
                    label_indices = label_indices[:eos_pos]
                else:
                    # remove <PAD> if present
                    label_indices = label_indices[label_indices != char_to_idx['<PAD>']]

                label_chars = [idx_to_char.get(idx, '') for idx in label_indices]
                label_str   = ''.join(label_chars)

                global_idx    = batch_idx * batch_size + i
                image_filename= test_data.iloc[global_idx]['filename']

                results.append({
                    'image_filename': image_filename,
                    'predicted_caption': pred_str,
                    'ground_truth_caption': label_str
                })

    return results

# %%
def calculate_global_cer(results):
    total_ed   = 0
    total_refs = 0
    for r in results:
        ref = r['ground_truth_caption']
        hyp = r['predicted_caption']
        dist = editdistance.eval(ref, hyp)
        total_ed   += dist
        total_refs += len(ref)
    if total_refs == 0:
        return 0.0
    return total_ed / total_refs

# %%
def print_top_worst_samples(results, n=5):
    # Calculate CER for each sample
    results_with_cer = []
    for r in results:
        ref = r['ground_truth_caption']
        hyp = r['predicted_caption']
        dist = editdistance.eval(ref, hyp)
        length = len(ref)
        cer = dist / length if length > 0 else 0
        # Copy the record and add cer
        new_r = r.copy()
        new_r['cer'] = cer
        results_with_cer.append(new_r)

    # Sort by CER (descending) and take the top N
    results_with_cer.sort(key=lambda x: x['cer'], reverse=True)
    worst_samples = results_with_cer[:n]

    print(f"\n=== Top {n} Worst Samples by CER ===")
    for i, sample in enumerate(worst_samples, start=1):
        print(f"{i}) Image: {sample['image_filename']}")
        print(f"   CER: {sample['cer']:.4f}")
        print(f"   Predicted       : {sample['predicted_caption']}")
        print(f"   Ground Truth    : {sample['ground_truth_caption']}")
        print()

# %%
# Ensure CSV files exist
training_csv = "training_results.csv"
if not os.path.exists(training_csv) or os.path.getsize(training_csv) == 0:
    pd.DataFrame(columns=["model_name", "mode", "epoch1", "epoch2"]).to_csv(training_csv, index=False)

csv_file = "test_cer_results.csv"
if not os.path.exists(csv_file) or os.path.getsize(csv_file) == 0:
    pd.DataFrame(columns=["model_name", "test_cer"]).to_csv(csv_file, index=False)

def log_test_cer(model_name, cer_value):
    """
    Logs or updates the test CER for a given model, rounding values to 4 decimals.
    """
    df = pd.read_csv(csv_file)
    
    # Round the new CER value to 4 decimals
    cer_rounded = round(cer_value, 4)
    
    if model_name in df['model_name'].values:
        # Update existing row
        df.loc[df['model_name'] == model_name, 'test_cer'] = cer_rounded
    else:
        # Add new row
        new_row = pd.DataFrame({
            "model_name": [model_name],
            "test_cer":   [cer_rounded]
        })
        df = pd.concat([df, new_row], ignore_index=True)
    
    # Ensure all stored values are rounded to 4 decimals
    df['test_cer'] = df['test_cer'].round(4)
    
    # Save back to CSV
    df.to_csv(csv_file, index=False)
    print(f"Logged {model_name}: {cer_rounded:.4f}")

# %%
def run_training_pipeline(encoder_class,encoder_kwargs, model_name,vocab_size,encoder_lr, decoder_lr,train_loader,
                          val_loader,test_loader,char_to_idx,idx_to_char,max_label_length,max_label_length_test,test_data,
                          device, num_epochs=100):
    #build encoder & grab its dimension
    encoder = encoder_class(**encoder_kwargs).to(device)
    # if encoder_dim is None (e.g. Swin), prime it with a dummy batch
    if encoder.encoder_dim is None:
        with torch.no_grad():
            dummy = torch.randn(1, 3, 224, 224, device=device)
            _ = encoder(dummy)
    enc_dim = encoder.encoder_dim

    #build decoder 
    decoder = DecoderRNN(
        attention_dim=256,
        embed_dim=256,
        decoder_dim=512,
        vocab_size=vocab_size,
        encoder_dim=enc_dim,
        teacher_forcing_ratio=0.5
    ).to(device)

    # loss, optimizers, trainer
    criterion = nn.CrossEntropyLoss(ignore_index=char_to_idx['<PAD>'])
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=encoder_lr)
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=decoder_lr)

    # trainer = ImageCaptioningTrainer(
    #     encoder=encoder,
    #     decoder=decoder,
    #     criterion=criterion,
    #     encoder_optimizer=encoder_optimizer,
    #     decoder_optimizer=decoder_optimizer,
    #     train_loader=train_loader,
    #     val_loader=val_loader,
    #     device=device,
    #     char_to_idx=char_to_idx,
    #     idx_to_char=idx_to_char,
    #     max_label_length=max_label_length,
    #     model_name=model_name)
    trainer = ImageCaptioningTrainer(
        encoder=encoder,
        decoder=decoder,
        criterion=criterion,
        encoder_optimizer=encoder_optimizer,
        decoder_optimizer=decoder_optimizer,
        train_loader=train_loader,
        val_loader=val_loader,
        test_loader=test_loader,  
        test_data=test_data,      
        max_label_length_test=max_label_length_test,  
        device=device,
        char_to_idx=char_to_idx,
        idx_to_char=idx_to_char,
        max_label_length=max_label_length,
        model_name=model_name
    )

    trainer.fit(num_epochs)

    encoder.eval()
    decoder.teacher_forcing_ratio = 0.0

    results = inference(
        encoder=encoder,
        decoder=decoder,
        data_loader=test_loader,
        device=device,
        char_to_idx=char_to_idx,
        idx_to_char=idx_to_char,
        max_seq_length=max_label_length_test,
        test_data=test_data
    )

    cer = calculate_global_cer(results)
    print(f"{model_name} — Test CER: {cer:.4f}")
    print_top_worst_samples(results, n=5)
    log_test_cer(model_name, cer)

    del encoder, decoder, trainer
    torch.cuda.empty_cache()
    print(f"Memory cleared for {model_name}")

# %%
run_training_pipeline(
    encoder_class = ResNet18Encoder,
    encoder_kwargs= {},                              
    model_name    = "resnet18_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100
# [1/100] Train Loss: 2.1643, Train CER: 0.7584 | Val Loss: 1.3774, Val CER: 0.3548
#
# Epoch 2/100
# [2/100] Train Loss: 1.6997, Train CER: 0.5266 | Val Loss: 0.8563, Val CER: 0.2389
#
# Epoch 3/100
# [3/100] Train Loss: 1.4226, Train CER: 0.4322 | Val Loss: 0.6163, Val CER: 0.1656
#
# Epoch 4/100
# [4/100] Train Loss: 1.2291, Train CER: 0.3686 | Val Loss: 0.4763, Val CER: 0.1224
#
# Epoch 5/100
# [5/100] Train Loss: 1.1146, Train CER: 0.3366 | Val Loss: 0.4015, Val CER: 0.1120
#
# Epoch 6/100
# [6/100] Train Loss: 1.0476, Train CER: 0.3181 | Val Loss: 0.3693, Val CER: 0.0957
#
# Epoch 7/100
# [7/100] Train Loss: 0.9921, Train CER: 0.2992 | Val Loss: 0.3153, Val CER: 0.0845
#
# Epoch 8/100
# [8/100] Train Loss: 0.9542, Train CER: 0.2880 | Val Loss: 0.2582, Val CER: 0.0679
#
# Epoch 9/100
# [9/100] Train Loss: 0.9155, Train CER: 0.2789 | Val Loss: 0.2667, Val CER: 0.0668
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 10/100
# [10/100] Train Loss: 0.8942, Train CER: 0.2720 | Val Loss: 0.2379, Val CER: 0.0630
#
# Epoch 11/100
# [11/100] Train Loss: 0.8478, Train CER: 0.2624 | Val Loss: 0.2301, Val CER: 0.0589
#
# Epoch 12/100
# [12/100] Train Loss: 0.8341, Train CER: 0.2592 | Val Loss: 0.2327, Val CER: 0.0612
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 13/100
# [13/100] Train Loss: 0.8087, Train CER: 0.2504 | Val Loss: 0.2462, Val CER: 0.0617
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 14/100
# [14/100] Train Loss: 0.7926, Train CER: 0.2466 | Val Loss: 0.2278, Val CER: 0.0566
#
# Epoch 15/100
# [15/100] Train Loss: 0.7891, Train CER: 0.2454 | Val Loss: 0.2450, Val CER: 0.0593
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 16/100
# [16/100] Train Loss: 0.7619, Train CER: 0.2386 | Val Loss: 0.2164, Val CER: 0.0585
#
# Epoch 17/100
# [17/100] Train Loss: 0.7607, Train CER: 0.2378 | Val Loss: 0.2194, Val CER: 0.0551
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 18/100
# [18/100] Train Loss: 0.7654, Train CER: 0.2379 | Val Loss: 0.2176, Val CER: 0.0563
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 19/100
# [19/100] Train Loss: 0.7192, Train CER: 0.2231 | Val Loss: 0.2353, Val CER: 0.0598
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 20/100
# [20/100] Train Loss: 0.7185, Train CER: 0.2241 | Val Loss: 0.1945, Val CER: 0.0474
#
# Epoch 21/100
# [21/100] Train Loss: 0.7184, Train CER: 0.2234 | Val Loss: 0.2199, Val CER: 0.0512
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 22/100
# [22/100] Train Loss: 0.7102, Train CER: 0.2227 | Val Loss: 0.2687, Val CER: 0.0676
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 23/100
# [23/100] Train Loss: 0.7014, Train CER: 0.2169 | Val Loss: 0.2192, Val CER: 0.0538
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 24/100
# [24/100] Train Loss: 0.7073, Train CER: 0.2193 | Val Loss: 0.2120, Val CER: 0.0551
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 25/100
# [25/100] Train Loss: 0.6882, Train CER: 0.2156 | Val Loss: 0.2120, Val CER: 0.0507
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 26/100
# [26/100] Train Loss: 0.7004, Train CER: 0.2204 | Val Loss: 0.2309, Val CER: 0.0530
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 27/100
# [27/100] Train Loss: 0.6835, Train CER: 0.2138 | Val Loss: 0.2305, Val CER: 0.0538
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 28/100
# [28/100] Train Loss: 0.6812, Train CER: 0.2133 | Val Loss: 0.2082, Val CER: 0.0506
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 29/100
# [29/100] Train Loss: 0.6673, Train CER: 0.2091 | Val Loss: 0.2215, Val CER: 0.0539
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 30/100
# [30/100] Train Loss: 0.6825, Train CER: 0.2163 | Val Loss: 0.2086, Val CER: 0.0497
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 2h 3m.
#
# Results have been written to: training_results.csv
# resnet18_encoder — Test CER: 0.1403
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 8.0000
#    Predicted       : sangsaga
#    Ground Truth    : .
#
# 2) Image: test4766.png
#    CER: 6.0000
#    Predicted       : gedang
#    Ground Truth    : i
#
# 3) Image: test6559.png
#    CER: 5.0000
#    Predicted       : bening
#    Ground Truth    : i
#
# 4) Image: test726.png
#    CER: 4.0000
#    Predicted       : sang
#    Ground Truth    : 6
#
# 5) Image: test783.png
#    CER: 4.0000
#    Predicted       : kang
#    Ground Truth    : l
#
# Logged resnet18_encoder: 0.1403
# Memory cleared for resnet18_encoder

# %%
run_training_pipeline(
    encoder_class = ViTEncoder,
    encoder_kwargs= {"model_name":"vit_base_patch16_224","pretrained":True},
    model_name    = "vit_base_patch16_224",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/100
# [1/100] Train Loss: 2.2171, Train CER: 0.7667 | Val Loss: 1.6267, Val CER: 0.4180
#
# Epoch 2/100
# [2/100] Train Loss: 1.8713, Train CER: 0.5864 | Val Loss: 1.1732, Val CER: 0.3532
#
# Epoch 3/100
# [3/100] Train Loss: 1.6156, Train CER: 0.4865 | Val Loss: 0.8382, Val CER: 0.2009
#
# Epoch 4/100
# [4/100] Train Loss: 1.3731, Train CER: 0.4102 | Val Loss: 0.5391, Val CER: 0.1343
#
# Epoch 5/100
# [5/100] Train Loss: 1.2124, Train CER: 0.3657 | Val Loss: 0.4369, Val CER: 0.1123
#
# Epoch 6/100
# [6/100] Train Loss: 1.1131, Train CER: 0.3366 | Val Loss: 0.3540, Val CER: 0.1016
#
# Epoch 7/100
# [7/100] Train Loss: 1.0597, Train CER: 0.3216 | Val Loss: 0.3126, Val CER: 0.0847
#
# Epoch 8/100
# [8/100] Train Loss: 0.9864, Train CER: 0.3041 | Val Loss: 0.2900, Val CER: 0.0796
#
# Epoch 9/100
# [9/100] Train Loss: 0.9582, Train CER: 0.2914 | Val Loss: 0.2496, Val CER: 0.0620
#
# Epoch 10/100
# [10/100] Train Loss: 0.9299, Train CER: 0.2826 | Val Loss: 0.2571, Val CER: 0.0673
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 11/100
# [11/100] Train Loss: 0.8823, Train CER: 0.2709 | Val Loss: 0.2407, Val CER: 0.0601
#
# Epoch 12/100
# [12/100] Train Loss: 0.8813, Train CER: 0.2707 | Val Loss: 0.2424, Val CER: 0.0667
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 13/100
# [13/100] Train Loss: 0.8671, Train CER: 0.2641 | Val Loss: 0.2297, Val CER: 0.0594
#
# Epoch 14/100
# [14/100] Train Loss: 0.8459, Train CER: 0.2596 | Val Loss: 0.2183, Val CER: 0.0614
#
# Epoch 15/100
# [15/100] Train Loss: 0.8266, Train CER: 0.2530 | Val Loss: 0.1912, Val CER: 0.0543
#
# Epoch 16/100
# [16/100] Train Loss: 0.8242, Train CER: 0.2542 | Val Loss: 0.2207, Val CER: 0.0537
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 17/100
# [17/100] Train Loss: 0.7976, Train CER: 0.2456 | Val Loss: 0.2183, Val CER: 0.0560
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 18/100
# [18/100] Train Loss: 0.8030, Train CER: 0.2499 | Val Loss: 0.1816, Val CER: 0.0473
#
# Epoch 19/100
# [19/100] Train Loss: 0.7780, Train CER: 0.2418 | Val Loss: 0.1946, Val CER: 0.0578
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 20/100
# [20/100] Train Loss: 0.7793, Train CER: 0.2376 | Val Loss: 0.2106, Val CER: 0.0536
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 21/100
# [21/100] Train Loss: 0.7798, Train CER: 0.2403 | Val Loss: 0.2277, Val CER: 0.0578
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 22/100
# [22/100] Train Loss: 0.7653, Train CER: 0.2400 | Val Loss: 0.2000, Val CER: 0.0514
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 23/100
# [23/100] Train Loss: 0.7594, Train CER: 0.2292 | Val Loss: 0.1808, Val CER: 0.0487
#
# Epoch 24/100
# [24/100] Train Loss: 0.7678, Train CER: 0.2382 | Val Loss: 0.1605, Val CER: 0.0473
#
# Epoch 25/100
# [25/100] Train Loss: 0.7385, Train CER: 0.2264 | Val Loss: 0.1962, Val CER: 0.0494
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 26/100
# [26/100] Train Loss: 0.7487, Train CER: 0.2295 | Val Loss: 0.1861, Val CER: 0.0430
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 27/100
# [27/100] Train Loss: 0.7482, Train CER: 0.2294 | Val Loss: 0.1455, Val CER: 0.0383
#
# Epoch 28/100
# [28/100] Train Loss: 0.7313, Train CER: 0.2273 | Val Loss: 0.1576, Val CER: 0.0430
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 29/100
# [29/100] Train Loss: 0.7558, Train CER: 0.2308 | Val Loss: 0.1930, Val CER: 0.0489
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 30/100
# [30/100] Train Loss: 0.7112, Train CER: 0.2182 | Val Loss: 0.1940, Val CER: 0.0475
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 31/100
# [31/100] Train Loss: 0.7052, Train CER: 0.2189 | Val Loss: 0.1756, Val CER: 0.0424
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 32/100
# [32/100] Train Loss: 0.7067, Train CER: 0.2200 | Val Loss: 0.1936, Val CER: 0.0494
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 33/100
# [33/100] Train Loss: 0.7011, Train CER: 0.2176 | Val Loss: 0.1495, Val CER: 0.0355
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 34/100
# [34/100] Train Loss: 0.7067, Train CER: 0.2182 | Val Loss: 0.1643, Val CER: 0.0408
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 35/100
# [35/100] Train Loss: 0.7162, Train CER: 0.2211 | Val Loss: 0.1833, Val CER: 0.0485
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 36/100
# [36/100] Train Loss: 0.7077, Train CER: 0.2205 | Val Loss: 0.1420, Val CER: 0.0375
#
# Epoch 37/100
# [37/100] Train Loss: 0.6964, Train CER: 0.2127 | Val Loss: 0.1536, Val CER: 0.0401
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 38/100
# [38/100] Train Loss: 0.6974, Train CER: 0.2154 | Val Loss: 0.1759, Val CER: 0.0468
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 39/100
# [39/100] Train Loss: 0.6970, Train CER: 0.2161 | Val Loss: 0.1865, Val CER: 0.0422
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 40/100
# [40/100] Train Loss: 0.6878, Train CER: 0.2125 | Val Loss: 0.1989, Val CER: 0.0468
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 41/100
# [41/100] Train Loss: 0.6922, Train CER: 0.2150 | Val Loss: 0.1961, Val CER: 0.0485
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 42/100
# [42/100] Train Loss: 0.6969, Train CER: 0.2133 | Val Loss: 0.1868, Val CER: 0.0471
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 43/100
# [43/100] Train Loss: 0.6812, Train CER: 0.2108 | Val Loss: 0.1903, Val CER: 0.0445
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 44/100
# [44/100] Train Loss: 0.6819, Train CER: 0.2105 | Val Loss: 0.1692, Val CER: 0.0390
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 45/100
# [45/100] Train Loss: 0.6776, Train CER: 0.2103 | Val Loss: 0.1576, Val CER: 0.0404
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 46/100
# [46/100] Train Loss: 0.6852, Train CER: 0.2133 | Val Loss: 0.1607, Val CER: 0.0414
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 3h 25m.
#
# Results have been written to: training_results.csv
# vit_base_patch16_224 — Test CER: 0.1333
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test262.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 2) Image: test3029.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 3) Image: test4934.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 4) Image: test9874.png
#    CER: 11.0000
#    Predicted       : carik-agung
#    Ground Truth    : .
#
# 5) Image: test1330.png
#    CER: 9.0000
#    Predicted       : paraksana
#    Ground Truth    : .
#
# Logged vit_base_patch16_224: 0.1333
# Memory cleared for vit_base_patch16_224

# %%
run_training_pipeline(
    encoder_class = ViTEncoder,
    encoder_kwargs= {"model_name": "vit_large_patch16_224", "pretrained": True},
    model_name    = "vit_large_patch16_224",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/100
# [1/100] Train Loss: 2.1634, Train CER: 0.7545 | Val Loss: 1.4151, Val CER: 0.4422
#
# Epoch 2/100
# [2/100] Train Loss: 1.7046, Train CER: 0.5333 | Val Loss: 0.9126, Val CER: 0.2349
#
# Epoch 3/100
# [3/100] Train Loss: 1.4164, Train CER: 0.4268 | Val Loss: 0.6003, Val CER: 0.1400
#
# Epoch 4/100
# [4/100] Train Loss: 1.2227, Train CER: 0.3689 | Val Loss: 0.4164, Val CER: 0.1120
#
# Epoch 5/100
# [5/100] Train Loss: 1.1138, Train CER: 0.3400 | Val Loss: 0.3433, Val CER: 0.1015
#
# Epoch 6/100
# [6/100] Train Loss: 1.0254, Train CER: 0.3170 | Val Loss: 0.3000, Val CER: 0.0815
#
# Epoch 7/100
# [7/100] Train Loss: 0.9693, Train CER: 0.2964 | Val Loss: 0.2424, Val CER: 0.0632
#
# Epoch 8/100
# [8/100] Train Loss: 0.9154, Train CER: 0.2810 | Val Loss: 0.2436, Val CER: 0.0699
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 9/100
# [9/100] Train Loss: 0.8909, Train CER: 0.2739 | Val Loss: 0.2510, Val CER: 0.0698
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 10/100
# [10/100] Train Loss: 0.8634, Train CER: 0.2643 | Val Loss: 0.1998, Val CER: 0.0494
#
# Epoch 11/100
# [11/100] Train Loss: 0.8585, Train CER: 0.2653 | Val Loss: 0.1997, Val CER: 0.0502
#
# Epoch 12/100
# [12/100] Train Loss: 0.8257, Train CER: 0.2535 | Val Loss: 0.2132, Val CER: 0.0545
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 13/100
# [13/100] Train Loss: 0.8068, Train CER: 0.2512 | Val Loss: 0.1922, Val CER: 0.0484
#
# Epoch 14/100
# [14/100] Train Loss: 0.8412, Train CER: 0.2616 | Val Loss: 0.1948, Val CER: 0.0512
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 15/100
# [15/100] Train Loss: 0.8035, Train CER: 0.2486 | Val Loss: 0.2032, Val CER: 0.0496
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 16/100
# [16/100] Train Loss: 0.7972, Train CER: 0.2474 | Val Loss: 0.1832, Val CER: 0.0500
#
# Epoch 17/100
# [17/100] Train Loss: 0.7648, Train CER: 0.2356 | Val Loss: 0.1794, Val CER: 0.0462
#
# Epoch 18/100
# [18/100] Train Loss: 0.7709, Train CER: 0.2376 | Val Loss: 0.1774, Val CER: 0.0456
#
# Epoch 19/100
# [19/100] Train Loss: 0.7637, Train CER: 0.2325 | Val Loss: 0.1650, Val CER: 0.0456
#
# Epoch 20/100
# [20/100] Train Loss: 0.7458, Train CER: 0.2271 | Val Loss: 0.1796, Val CER: 0.0439
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 21/100
# [21/100] Train Loss: 0.7755, Train CER: 0.2403 | Val Loss: 0.1941, Val CER: 0.0525
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 22/100
# [22/100] Train Loss: 0.7459, Train CER: 0.2314 | Val Loss: 0.1439, Val CER: 0.0423
#
# Epoch 23/100
# [23/100] Train Loss: 0.7224, Train CER: 0.2267 | Val Loss: 0.1834, Val CER: 0.0459
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 24/100
# [24/100] Train Loss: 0.7378, Train CER: 0.2267 | Val Loss: 0.1716, Val CER: 0.0447
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 25/100
# [25/100] Train Loss: 0.7302, Train CER: 0.2270 | Val Loss: 0.1828, Val CER: 0.0448
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 26/100
# [26/100] Train Loss: 0.7208, Train CER: 0.2216 | Val Loss: 0.2117, Val CER: 0.0540
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 27/100
# [27/100] Train Loss: 0.7413, Train CER: 0.2323 | Val Loss: 0.1627, Val CER: 0.0407
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 28/100
# [28/100] Train Loss: 0.6939, Train CER: 0.2168 | Val Loss: 0.1708, Val CER: 0.0382
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 29/100
# [29/100] Train Loss: 0.7035, Train CER: 0.2170 | Val Loss: 0.1562, Val CER: 0.0364
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 30/100
# [30/100] Train Loss: 0.7106, Train CER: 0.2182 | Val Loss: 0.1916, Val CER: 0.0429
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 31/100
# [31/100] Train Loss: 0.7047, Train CER: 0.2192 | Val Loss: 0.1855, Val CER: 0.0474
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 32/100
# [32/100] Train Loss: 0.6923, Train CER: 0.2131 | Val Loss: 0.1720, Val CER: 0.0445
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 3h 20m.
#
# Results have been written to: training_results.csv
# vit_large_patch16_224 — Test CER: 0.1254
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test3142.png
#    CER: 5.0000
#    Predicted       : shang
#    Ground Truth    : i
#
# 2) Image: test6297.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 3) Image: test9386.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 4) Image: test1335.png
#    CER: 4.0000
#    Predicted       : pari
#    Ground Truth    : .
#
# 5) Image: test2052.png
#    CER: 4.0000
#    Predicted       : rawa
#    Ground Truth    : .
#
# Logged vit_large_patch16_224: 0.1254
# Memory cleared for vit_large_patch16_224

# %%
run_training_pipeline(
    encoder_class = HybridEncoder,
    encoder_kwargs= {
        "cnn_encoder": ResNet18Encoder(pretrained=True),
        "vit_encoder": ViTEncoder(model_name="vit_base_patch16_224", pretrained=True)
    },
    model_name    = "hybrid_cnn_vit_base_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100
# [1/100] Train Loss: 2.1949, Train CER: 0.7635 | Val Loss: 1.5478, Val CER: 0.4189
#
# Epoch 2/100
# [2/100] Train Loss: 1.7782, Train CER: 0.5472 | Val Loss: 0.9815, Val CER: 0.2535
#
# Epoch 3/100
# [3/100] Train Loss: 1.4644, Train CER: 0.4366 | Val Loss: 0.6568, Val CER: 0.1781
#
# Epoch 4/100
# [4/100] Train Loss: 1.2875, Train CER: 0.3840 | Val Loss: 0.4920, Val CER: 0.1237
#
# Epoch 5/100
# [5/100] Train Loss: 1.1637, Train CER: 0.3505 | Val Loss: 0.3979, Val CER: 0.1083
#
# Epoch 6/100
# [6/100] Train Loss: 1.0812, Train CER: 0.3288 | Val Loss: 0.3791, Val CER: 0.0965
#
# Epoch 7/100
# [7/100] Train Loss: 1.0072, Train CER: 0.3025 | Val Loss: 0.3191, Val CER: 0.0768
#
# Epoch 8/100
# [8/100] Train Loss: 0.9756, Train CER: 0.2965 | Val Loss: 0.3008, Val CER: 0.0798
#
# Epoch 9/100
# [9/100] Train Loss: 0.9179, Train CER: 0.2768 | Val Loss: 0.2792, Val CER: 0.0691
#
# Epoch 10/100
# [10/100] Train Loss: 0.8935, Train CER: 0.2730 | Val Loss: 0.2743, Val CER: 0.0653
#
# Epoch 11/100
# [11/100] Train Loss: 0.8699, Train CER: 0.2685 | Val Loss: 0.2618, Val CER: 0.0711
#
# Epoch 12/100
# [12/100] Train Loss: 0.8687, Train CER: 0.2715 | Val Loss: 0.2635, Val CER: 0.0677
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 13/100
# [13/100] Train Loss: 0.8316, Train CER: 0.2562 | Val Loss: 0.2496, Val CER: 0.0706
#
# Epoch 14/100
# [14/100] Train Loss: 0.8188, Train CER: 0.2519 | Val Loss: 0.2382, Val CER: 0.0609
#
# Epoch 15/100
# [15/100] Train Loss: 0.8205, Train CER: 0.2555 | Val Loss: 0.2331, Val CER: 0.0620
#
# Epoch 16/100
# [16/100] Train Loss: 0.7821, Train CER: 0.2391 | Val Loss: 0.2300, Val CER: 0.0564
#
# Epoch 17/100
# [17/100] Train Loss: 0.7685, Train CER: 0.2368 | Val Loss: 0.2433, Val CER: 0.0627
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 18/100
# [18/100] Train Loss: 0.7570, Train CER: 0.2325 | Val Loss: 0.2441, Val CER: 0.0624
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 19/100
# [19/100] Train Loss: 0.7382, Train CER: 0.2295 | Val Loss: 0.2238, Val CER: 0.0567
#
# Epoch 20/100
# [20/100] Train Loss: 0.7398, Train CER: 0.2343 | Val Loss: 0.2218, Val CER: 0.0546
#
# Epoch 21/100
# [21/100] Train Loss: 0.7421, Train CER: 0.2329 | Val Loss: 0.2552, Val CER: 0.0614
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 22/100
# [22/100] Train Loss: 0.7463, Train CER: 0.2339 | Val Loss: 0.2343, Val CER: 0.0543
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 23/100
# [23/100] Train Loss: 0.7119, Train CER: 0.2212 | Val Loss: 0.2272, Val CER: 0.0489
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 24/100
# [24/100] Train Loss: 0.7023, Train CER: 0.2205 | Val Loss: 0.2445, Val CER: 0.0559
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 25/100
# [25/100] Train Loss: 0.7138, Train CER: 0.2282 | Val Loss: 0.2247, Val CER: 0.0601
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 26/100
# [26/100] Train Loss: 0.7022, Train CER: 0.2203 | Val Loss: 0.2641, Val CER: 0.0639
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 27/100
# [27/100] Train Loss: 0.6865, Train CER: 0.2147 | Val Loss: 0.2225, Val CER: 0.0553
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 28/100
# [28/100] Train Loss: 0.6931, Train CER: 0.2194 | Val Loss: 0.2155, Val CER: 0.0544
#
# Epoch 29/100
# [29/100] Train Loss: 0.7023, Train CER: 0.2173 | Val Loss: 0.2282, Val CER: 0.0532
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 30/100
# [30/100] Train Loss: 0.6713, Train CER: 0.2069 | Val Loss: 0.2380, Val CER: 0.0545
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 31/100
# [31/100] Train Loss: 0.6781, Train CER: 0.2186 | Val Loss: 0.2080, Val CER: 0.0439
#
# Epoch 32/100
# [32/100] Train Loss: 0.6542, Train CER: 0.2031 | Val Loss: 0.2300, Val CER: 0.0577
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 33/100
# [33/100] Train Loss: 0.6836, Train CER: 0.2152 | Val Loss: 0.2737, Val CER: 0.0599
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 34/100
# [34/100] Train Loss: 0.6701, Train CER: 0.2075 | Val Loss: 0.2414, Val CER: 0.0608
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 35/100
# [35/100] Train Loss: 0.6544, Train CER: 0.2027 | Val Loss: 0.2143, Val CER: 0.0531
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 36/100
# [36/100] Train Loss: 0.6898, Train CER: 0.2164 | Val Loss: 0.2473, Val CER: 0.0567
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 37/100
# [37/100] Train Loss: 0.6671, Train CER: 0.2090 | Val Loss: 0.2751, Val CER: 0.0625
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 38/100
# [38/100] Train Loss: 0.6705, Train CER: 0.2083 | Val Loss: 0.2215, Val CER: 0.0540
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 39/100
# [39/100] Train Loss: 0.6587, Train CER: 0.2063 | Val Loss: 0.2137, Val CER: 0.0458
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 40/100
# [40/100] Train Loss: 0.6645, Train CER: 0.2077 | Val Loss: 0.2356, Val CER: 0.0608
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 41/100
# [41/100] Train Loss: 0.6316, Train CER: 0.1975 | Val Loss: 0.2395, Val CER: 0.0576
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 3h 3m.
#
# Results have been written to: training_results.csv
# hybrid_cnn_vit_base_encoder — Test CER: 0.1380
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 10.0000
#    Predicted       : sangluanpa
#    Ground Truth    : .
#
# 2) Image: test580.png
#    CER: 5.0000
#    Predicted       : .yanga
#    Ground Truth    : .
#
# 3) Image: test1335.png
#    CER: 5.0000
#    Predicted       : panta
#    Ground Truth    : .
#
# 4) Image: test6297.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 5) Image: test9386.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# Logged hybrid_cnn_vit_base_encoder: 0.1380
# Memory cleared for hybrid_cnn_vit_base_encoder

# %%
run_training_pipeline(
    encoder_class = HybridEncoder,
    encoder_kwargs= {
        "cnn_encoder": ResNet18Encoder(pretrained=True),
        "vit_encoder": ViTEncoder(model_name="vit_large_patch16_224", pretrained=True)
    },
    model_name    = "hybrid_cnn_vit_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 1e-4,
    decoder_lr    = 4e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /apps/miniforge3/24.3.0-0/miniforge3/envs/dsks_2024.06/lib/python3.9/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1/100
# [1/100] Train Loss: 2.2011, Train CER: 0.7652 | Val Loss: 1.6255, Val CER: 0.4708
#
# Epoch 2/100
# [2/100] Train Loss: 1.7848, Train CER: 0.5495 | Val Loss: 0.9991, Val CER: 0.2567
#
# Epoch 3/100
# [3/100] Train Loss: 1.4740, Train CER: 0.4425 | Val Loss: 0.6696, Val CER: 0.1582
#
# Epoch 4/100
# [4/100] Train Loss: 1.2966, Train CER: 0.3834 | Val Loss: 0.5820, Val CER: 0.1650
#
# Epoch 5/100
# [5/100] Train Loss: 1.1747, Train CER: 0.3489 | Val Loss: 0.3917, Val CER: 0.1034
#
# Epoch 6/100
# [6/100] Train Loss: 1.0970, Train CER: 0.3264 | Val Loss: 0.3286, Val CER: 0.0827
#
# Epoch 7/100
# [7/100] Train Loss: 1.0328, Train CER: 0.3101 | Val Loss: 0.3227, Val CER: 0.0784
#
# Epoch 8/100
# [8/100] Train Loss: 0.9776, Train CER: 0.2916 | Val Loss: 0.3003, Val CER: 0.0727
#
# Epoch 9/100
# [9/100] Train Loss: 0.9311, Train CER: 0.2788 | Val Loss: 0.2839, Val CER: 0.0711
#
# Epoch 10/100
# [10/100] Train Loss: 0.9440, Train CER: 0.2850 | Val Loss: 0.2623, Val CER: 0.0773
#
# Epoch 11/100
# [11/100] Train Loss: 0.8938, Train CER: 0.2764 | Val Loss: 0.2737, Val CER: 0.0705
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 12/100
# [12/100] Train Loss: 0.8767, Train CER: 0.2706 | Val Loss: 0.2043, Val CER: 0.0535
#
# Epoch 13/100
# [13/100] Train Loss: 0.8380, Train CER: 0.2581 | Val Loss: 0.2478, Val CER: 0.0669
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 14/100
# [14/100] Train Loss: 0.8301, Train CER: 0.2551 | Val Loss: 0.2382, Val CER: 0.0585
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 15/100
# [15/100] Train Loss: 0.8206, Train CER: 0.2508 | Val Loss: 0.2078, Val CER: 0.0546
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 16/100
# [16/100] Train Loss: 0.8009, Train CER: 0.2456 | Val Loss: 0.2080, Val CER: 0.0536
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 17/100
# [17/100] Train Loss: 0.8257, Train CER: 0.2524 | Val Loss: 0.2286, Val CER: 0.0607
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 18/100
# [18/100] Train Loss: 0.7852, Train CER: 0.2373 | Val Loss: 0.2213, Val CER: 0.0547
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 19/100
# [19/100] Train Loss: 0.7773, Train CER: 0.2371 | Val Loss: 0.2187, Val CER: 0.0575
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 20/100
# [20/100] Train Loss: 0.7588, Train CER: 0.2320 | Val Loss: 0.2186, Val CER: 0.0599
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 21/100
# [21/100] Train Loss: 0.7632, Train CER: 0.2343 | Val Loss: 0.2067, Val CER: 0.0567
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 22/100
# [22/100] Train Loss: 0.7722, Train CER: 0.2371 | Val Loss: 0.2555, Val CER: 0.0646
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 2h 20m.
#
# Results have been written to: training_results.csv
# hybrid_cnn_vit_encoder — Test CER: 0.1505
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 10.0000
#    Predicted       : pangamaapa
#    Ground Truth    : .
#
# 2) Image: test10070.png
#    CER: 10.0000
#    Predicted       : ngapangsia
#    Ground Truth    : .
#
# 3) Image: test3140.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 4) Image: test4687.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 5) Image: test6274.png
#    CER: 9.0000
#    Predicted       : nungkunia
#    Ground Truth    : .
#
# Logged hybrid_cnn_vit_encoder: 0.1505
# Memory cleared for hybrid_cnn_vit_encoder

# %%
run_training_pipeline(
    encoder_class=SwinEncoder,
    encoder_kwargs={"model_name":"swin_small_patch4_window7_224","pretrained":True},
    model_name="swin_small_encoder",
    vocab_size=vocab_size,
    encoder_lr=1e-4,
    decoder_lr=4e-4,
    train_loader=train_loader,
    val_loader=val_loader,
    test_loader=test_loader,
    char_to_idx=char_to_idx,
    idx_to_char=idx_to_char,
    max_label_length=max_label_length,
    max_label_length_test=max_label_length_test,
    test_data=test_data,
    device=device)
# Out:
# Epoch 1/100
# [1/100] Train Loss: 2.2995, Train CER: 0.8598 | Val Loss: 1.7796, Val CER: 0.4964
#
# Epoch 2/100
# [2/100] Train Loss: 2.0696, Train CER: 0.6456 | Val Loss: 1.6938, Val CER: 0.4661
#
# Epoch 3/100
# [3/100] Train Loss: 1.9893, Train CER: 0.6176 | Val Loss: 1.6039, Val CER: 0.4448
#
# Epoch 4/100
# [4/100] Train Loss: 1.9145, Train CER: 0.5847 | Val Loss: 1.4739, Val CER: 0.3755
#
# Epoch 5/100
# [5/100] Train Loss: 1.8467, Train CER: 0.5544 | Val Loss: 1.4168, Val CER: 0.3693
#
# Epoch 6/100
# [6/100] Train Loss: 1.7781, Train CER: 0.5284 | Val Loss: 1.2535, Val CER: 0.3033
#
# Epoch 7/100
# [7/100] Train Loss: 1.7204, Train CER: 0.5002 | Val Loss: 1.1561, Val CER: 0.2703
#
# Epoch 8/100
# [8/100] Train Loss: 1.6451, Train CER: 0.4703 | Val Loss: 1.0757, Val CER: 0.2749
#
# Epoch 9/100
# [9/100] Train Loss: 1.5929, Train CER: 0.4489 | Val Loss: 1.0261, Val CER: 0.2732
#
# Epoch 10/100
# [10/100] Train Loss: 1.5160, Train CER: 0.4178 | Val Loss: 0.8659, Val CER: 0.1914
#
# Epoch 11/100
# [11/100] Train Loss: 1.4571, Train CER: 0.4106 | Val Loss: 0.8025, Val CER: 0.1702
#
# Epoch 12/100
# [12/100] Train Loss: 1.4038, Train CER: 0.3901 | Val Loss: 0.7157, Val CER: 0.1537
#
# Epoch 13/100
# [13/100] Train Loss: 1.3457, Train CER: 0.3741 | Val Loss: 0.6726, Val CER: 0.1451
#
# Epoch 14/100
# [14/100] Train Loss: 1.2880, Train CER: 0.3582 | Val Loss: 0.6143, Val CER: 0.1428
#
# Epoch 15/100
# [15/100] Train Loss: 1.2345, Train CER: 0.3468 | Val Loss: 0.5450, Val CER: 0.1207
#
# Epoch 16/100
# [16/100] Train Loss: 1.1849, Train CER: 0.3308 | Val Loss: 0.4868, Val CER: 0.1114
#
# Epoch 17/100
# [17/100] Train Loss: 1.1463, Train CER: 0.3258 | Val Loss: 0.4584, Val CER: 0.0946
#
# Epoch 18/100
# [18/100] Train Loss: 1.1150, Train CER: 0.3140 | Val Loss: 0.4015, Val CER: 0.0930
#
# Epoch 19/100
# [19/100] Train Loss: 1.0814, Train CER: 0.3046 | Val Loss: 0.4054, Val CER: 0.0875
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 20/100
# [20/100] Train Loss: 1.0360, Train CER: 0.2956 | Val Loss: 0.3614, Val CER: 0.0781
#
# Epoch 21/100
# [21/100] Train Loss: 1.0023, Train CER: 0.2821 | Val Loss: 0.3493, Val CER: 0.0774
#
# Epoch 22/100
# [22/100] Train Loss: 0.9873, Train CER: 0.2838 | Val Loss: 0.3463, Val CER: 0.0744
#
# Epoch 23/100
# [23/100] Train Loss: 0.9681, Train CER: 0.2796 | Val Loss: 0.3020, Val CER: 0.0640
#
# Epoch 24/100
# [24/100] Train Loss: 0.9463, Train CER: 0.2743 | Val Loss: 0.3111, Val CER: 0.0656
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 25/100
# [25/100] Train Loss: 0.9176, Train CER: 0.2646 | Val Loss: 0.2832, Val CER: 0.0597
#
# Epoch 26/100
# [26/100] Train Loss: 0.9027, Train CER: 0.2620 | Val Loss: 0.2678, Val CER: 0.0592
#
# Epoch 27/100
# [27/100] Train Loss: 0.8734, Train CER: 0.2526 | Val Loss: 0.2642, Val CER: 0.0597
#
# Epoch 28/100
# [28/100] Train Loss: 0.8763, Train CER: 0.2526 | Val Loss: 0.2555, Val CER: 0.0567
#
# Epoch 29/100
# [29/100] Train Loss: 0.8569, Train CER: 0.2514 | Val Loss: 0.2449, Val CER: 0.0519
#
# Epoch 30/100
# [30/100] Train Loss: 0.8488, Train CER: 0.2503 | Val Loss: 0.2679, Val CER: 0.0609
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 31/100
# [32/100] Train Loss: 0.8222, Train CER: 0.2423 | Val Loss: 0.2410, Val CER: 0.0536
#
# Epoch 33/100
# [33/100] Train Loss: 0.8175, Train CER: 0.2391 | Val Loss: 0.2578, Val CER: 0.0538
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 34/100
# [34/100] Train Loss: 0.8051, Train CER: 0.2352 | Val Loss: 0.2170, Val CER: 0.0496
#
# Epoch 35/100
# [35/100] Train Loss: 0.7912, Train CER: 0.2339 | Val Loss: 0.2403, Val CER: 0.0481
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 36/100
# [36/100] Train Loss: 0.7895, Train CER: 0.2320 | Val Loss: 0.2328, Val CER: 0.0506
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 37/100
# [37/100] Train Loss: 0.7722, Train CER: 0.2277 | Val Loss: 0.2354, Val CER: 0.0491
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 38/100
# [38/100] Train Loss: 0.7759, Train CER: 0.2271 | Val Loss: 0.2551, Val CER: 0.0568
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 39/100
# [39/100] Train Loss: 0.7722, Train CER: 0.2294 | Val Loss: 0.2354, Val CER: 0.0593
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 40/100
# [40/100] Train Loss: 0.7531, Train CER: 0.2226 | Val Loss: 0.2181, Val CER: 0.0481
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 41/100
# [41/100] Train Loss: 0.7569, Train CER: 0.2235 | Val Loss: 0.2308, Val CER: 0.0500
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 42/100
# [42/100] Train Loss: 0.7485, Train CER: 0.2218 | Val Loss: 0.2315, Val CER: 0.0494
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 43/100
# [43/100] Train Loss: 0.7617, Train CER: 0.2328 | Val Loss: 0.2467, Val CER: 0.0476
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 44/100
# [44/100] Train Loss: 0.7227, Train CER: 0.2155 | Val Loss: 0.2251, Val CER: 0.0493
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 3h 16m.
#
# Results have been written to: training_results.csv
# swin_small_encoder — Test CER: 0.1755
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 7.0000
#    Predicted       : andaala
#    Ground Truth    : .
#
# 2) Image: test580.png
#    CER: 5.0000
#    Predicted       : kiang
#    Ground Truth    : .
#
# 3) Image: test1335.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 4) Image: test3804.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 5) Image: test3828.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# Logged swin_small_encoder: 0.1755
# Memory cleared for swin_small_encoder

# %%
run_training_pipeline(
    encoder_class = SwinEncoder,
    encoder_kwargs= {"model_name": "swin_base_patch4_window7_224", "pretrained": True},
    model_name    = "swin_base_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 8e-5,    # lower LR for the larger Swin
    decoder_lr    = 3e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/100
# [1/100] Train Loss: 2.3305, Train CER: 0.8666 | Val Loss: 1.8078, Val CER: 0.4991
#
# Epoch 2/100
# [2/100] Train Loss: 2.0743, Train CER: 0.6528 | Val Loss: 1.7196, Val CER: 0.4810
#
# Epoch 3/100
# [3/100] Train Loss: 1.9999, Train CER: 0.6209 | Val Loss: 1.6116, Val CER: 0.4342
#
# Epoch 4/100
# [4/100] Train Loss: 1.9348, Train CER: 0.5915 | Val Loss: 1.5199, Val CER: 0.3707
#
# Epoch 5/100
# [5/100] Train Loss: 1.8821, Train CER: 0.5623 | Val Loss: 1.4397, Val CER: 0.3825
#
# Epoch 6/100
# [6/100] Train Loss: 1.8369, Train CER: 0.5466 | Val Loss: 1.3899, Val CER: 0.3403
#
# Epoch 7/100
# [7/100] Train Loss: 1.7948, Train CER: 0.5271 | Val Loss: 1.2994, Val CER: 0.3167
#
# Epoch 8/100
# [8/100] Train Loss: 1.7391, Train CER: 0.5007 | Val Loss: 1.2252, Val CER: 0.3037
#
# Epoch 9/100
# [9/100] Train Loss: 1.6742, Train CER: 0.4720 | Val Loss: 1.1371, Val CER: 0.2574
#
# Epoch 10/100
# [10/100] Train Loss: 1.6312, Train CER: 0.4575 | Val Loss: 1.0843, Val CER: 0.2570
#
# Epoch 11/100
# [11/100] Train Loss: 1.5825, Train CER: 0.4416 | Val Loss: 1.0279, Val CER: 0.2480
#
# Epoch 12/100
# [12/100] Train Loss: 1.5336, Train CER: 0.4258 | Val Loss: 0.9332, Val CER: 0.2133
#
# Epoch 13/100
# [13/100] Train Loss: 1.4994, Train CER: 0.4172 | Val Loss: 0.8692, Val CER: 0.1940
#
# Epoch 14/100
# [14/100] Train Loss: 1.4287, Train CER: 0.3944 | Val Loss: 0.7924, Val CER: 0.1956
#
# Epoch 15/100
# [15/100] Train Loss: 1.3924, Train CER: 0.3865 | Val Loss: 0.7147, Val CER: 0.1587
#
# Epoch 16/100
# [16/100] Train Loss: 1.3583, Train CER: 0.3786 | Val Loss: 0.6584, Val CER: 0.1378
#
# Epoch 17/100
# [17/100] Train Loss: 1.2951, Train CER: 0.3584 | Val Loss: 0.6147, Val CER: 0.1364
#
# Epoch 18/100
# [18/100] Train Loss: 1.2455, Train CER: 0.3448 | Val Loss: 0.5379, Val CER: 0.1106
#
# Epoch 19/100
# [19/100] Train Loss: 1.2131, Train CER: 0.3411 | Val Loss: 0.5409, Val CER: 0.1318
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 20/100
# [20/100] Train Loss: 1.1724, Train CER: 0.3281 | Val Loss: 0.5027, Val CER: 0.1239
#
# Epoch 21/100
# [21/100] Train Loss: 1.1155, Train CER: 0.3099 | Val Loss: 0.4387, Val CER: 0.1024
#
# Epoch 22/100
# [22/100] Train Loss: 1.1086, Train CER: 0.3119 | Val Loss: 0.4053, Val CER: 0.0929
#
# Epoch 23/100
# [23/100] Train Loss: 1.0824, Train CER: 0.3074 | Val Loss: 0.4202, Val CER: 0.0953
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 24/100
# [24/100] Train Loss: 1.0514, Train CER: 0.2966 | Val Loss: 0.3886, Val CER: 0.0889
#
# Epoch 25/100
# [25/100] Train Loss: 1.0298, Train CER: 0.2919 | Val Loss: 0.4341, Val CER: 0.1100
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 26/100
# [26/100] Train Loss: 0.9971, Train CER: 0.2834 | Val Loss: 0.3485, Val CER: 0.0825
#
# Epoch 27/100
# [27/100] Train Loss: 0.9688, Train CER: 0.2757 | Val Loss: 0.3341, Val CER: 0.0771
#
# Epoch 28/100
# [28/100] Train Loss: 0.9412, Train CER: 0.2679 | Val Loss: 0.3205, Val CER: 0.0706
#
# Epoch 29/100
# [29/100] Train Loss: 0.9341, Train CER: 0.2667 | Val Loss: 0.3053, Val CER: 0.0670
#
# Epoch 30/100
# [30/100] Train Loss: 0.9206, Train CER: 0.2655 | Val Loss: 0.2913, Val CER: 0.0631
#
# Epoch 31/100
# [31/100] Train Loss: 0.8921, Train CER: 0.2584 | Val Loss: 0.2980, Val CER: 0.0674
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 32/100
# [32/100] Train Loss: 0.8750, Train CER: 0.2536 | Val Loss: 0.3462, Val CER: 0.0807
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 33/100
# [33/100] Train Loss: 0.8773, Train CER: 0.2522 | Val Loss: 0.2888, Val CER: 0.0651
#
# Epoch 34/100
# [34/100] Train Loss: 0.8641, Train CER: 0.2522 | Val Loss: 0.3198, Val CER: 0.0646
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 35/100
# [35/100] Train Loss: 0.8593, Train CER: 0.2537 | Val Loss: 0.3023, Val CER: 0.0662
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 36/100
# [36/100] Train Loss: 0.8430, Train CER: 0.2478 | Val Loss: 0.2893, Val CER: 0.0625
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 37/100
# [37/100] Train Loss: 0.8251, Train CER: 0.2435 | Val Loss: 0.2841, Val CER: 0.0658
#
# Epoch 38/100
# [38/100] Train Loss: 0.8041, Train CER: 0.2360 | Val Loss: 0.2736, Val CER: 0.0625
#
# Epoch 39/100
# [39/100] Train Loss: 0.8142, Train CER: 0.2411 | Val Loss: 0.2900, Val CER: 0.0677
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 40/100
# [40/100] Train Loss: 0.7868, Train CER: 0.2332 | Val Loss: 0.2633, Val CER: 0.0648
#
# Epoch 41/100
# [41/100] Train Loss: 0.7862, Train CER: 0.2326 | Val Loss: 0.2571, Val CER: 0.0585
#
# Epoch 42/100
# [42/100] Train Loss: 0.7854, Train CER: 0.2305 | Val Loss: 0.2603, Val CER: 0.0553
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 43/100
# [43/100] Train Loss: 0.7781, Train CER: 0.2319 | Val Loss: 0.2832, Val CER: 0.0646
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 44/100
# [44/100] Train Loss: 0.7711, Train CER: 0.2259 | Val Loss: 0.2567, Val CER: 0.0617
#
# Epoch 45/100
# [45/100] Train Loss: 0.7537, Train CER: 0.2256 | Val Loss: 0.2468, Val CER: 0.0524
#
# Epoch 46/100
# [46/100] Train Loss: 0.7538, Train CER: 0.2238 | Val Loss: 0.2797, Val CER: 0.0536
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 47/100
# [47/100] Train Loss: 0.7485, Train CER: 0.2231 | Val Loss: 0.2467, Val CER: 0.0562
#
# Epoch 48/100
# [48/100] Train Loss: 0.7568, Train CER: 0.2261 | Val Loss: 0.2450, Val CER: 0.0558
#
# Epoch 49/100
# [49/100] Train Loss: 0.7165, Train CER: 0.2133 | Val Loss: 0.2449, Val CER: 0.0537
#
# Epoch 50/100
# [50/100] Train Loss: 0.7247, Train CER: 0.2144 | Val Loss: 0.2635, Val CER: 0.0585
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 51/100
# [51/100] Train Loss: 0.7042, Train CER: 0.2099 | Val Loss: 0.2362, Val CER: 0.0514
#
# Epoch 52/100
# [52/100] Train Loss: 0.7196, Train CER: 0.2153 | Val Loss: 0.2491, Val CER: 0.0514
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 53/100
# [53/100] Train Loss: 0.7016, Train CER: 0.2111 | Val Loss: 0.2728, Val CER: 0.0553
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 54/100
# [54/100] Train Loss: 0.7235, Train CER: 0.2132 | Val Loss: 0.2413, Val CER: 0.0529
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 55/100
# [55/100] Train Loss: 0.7116, Train CER: 0.2085 | Val Loss: 0.2466, Val CER: 0.0487
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 56/100
# [56/100] Train Loss: 0.7229, Train CER: 0.2121 | Val Loss: 0.2458, Val CER: 0.0484
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 57/100
# [57/100] Train Loss: 0.7159, Train CER: 0.2106 | Val Loss: 0.2482, Val CER: 0.0510
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 58/100
# [58/100] Train Loss: 0.7031, Train CER: 0.2111 | Val Loss: 0.2293, Val CER: 0.0514
#
# Epoch 59/100
# [59/100] Train Loss: 0.6994, Train CER: 0.2095 | Val Loss: 0.2377, Val CER: 0.0476
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 60/100
# [60/100] Train Loss: 0.7077, Train CER: 0.2178 | Val Loss: 0.2433, Val CER: 0.0513
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 61/100
# [61/100] Train Loss: 0.6824, Train CER: 0.2047 | Val Loss: 0.2593, Val CER: 0.0592
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 62/100
# [62/100] Train Loss: 0.7001, Train CER: 0.2098 | Val Loss: 0.2694, Val CER: 0.0575
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 63/100
# [63/100] Train Loss: 0.6856, Train CER: 0.2067 | Val Loss: 0.2572, Val CER: 0.0546
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 64/100
# [64/100] Train Loss: 0.6640, Train CER: 0.1980 | Val Loss: 0.2317, Val CER: 0.0496
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 65/100
# [65/100] Train Loss: 0.6882, Train CER: 0.2068 | Val Loss: 0.2578, Val CER: 0.0513
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 66/100
# [66/100] Train Loss: 0.6734, Train CER: 0.2007 | Val Loss: 0.3008, Val CER: 0.0577
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 67/100
# [67/100] Train Loss: 0.7028, Train CER: 0.2082 | Val Loss: 0.2425, Val CER: 0.0521
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 68/100
# [68/100] Train Loss: 0.6778, Train CER: 0.2040 | Val Loss: 0.2396, Val CER: 0.0552
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 5h 16m.
#
# Results have been written to: training_results.csv
# swin_base_encoder — Test CER: 0.1793
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test3617.png
#    CER: 9.0000
#    Predicted       : adeg-adeg
#    Ground Truth    : ,
#
# 2) Image: test1330.png
#    CER: 8.0000
#    Predicted       : sangaaya
#    Ground Truth    : .
#
# 3) Image: test8657.png
#    CER: 5.0000
#    Predicted       : panti
#    Ground Truth    : .
#
# 4) Image: test585.png
#    CER: 4.0000
#    Predicted       : yang
#    Ground Truth    : 9
#
# 5) Image: test1287.png
#    CER: 4.0000
#    Predicted       : yang
#    Ground Truth    : 7
#
# Logged swin_base_encoder: 0.1793
# Memory cleared for swin_base_encoder

# %%
run_training_pipeline(
    encoder_class = SwinEncoder,
    encoder_kwargs= {"model_name": "swin_large_patch4_window7_224", "pretrained": True},
    model_name    = "swin_large_encoder",
    vocab_size    = vocab_size,
    encoder_lr    = 5e-5,
    decoder_lr    = 2e-4,
    train_loader  = train_loader,
    val_loader    = val_loader,
    test_loader   = test_loader,
    char_to_idx   = char_to_idx,
    idx_to_char   = idx_to_char,
    max_label_length      = max_label_length,
    max_label_length_test = max_label_length_test,
    test_data      = test_data,
    device         = device)
# Out:
# Epoch 1/100
# [1/100] Train Loss: 2.3967, Train CER: 0.8997 | Val Loss: 1.8994, Val CER: 0.5508
#
# Epoch 2/100
# [2/100] Train Loss: 2.0979, Train CER: 0.6664 | Val Loss: 1.7622, Val CER: 0.4357
#
# Epoch 3/100
# [3/100] Train Loss: 2.0408, Train CER: 0.6295 | Val Loss: 1.6888, Val CER: 0.4367
#
# Epoch 4/100
# [4/100] Train Loss: 2.0132, Train CER: 0.6053 | Val Loss: 1.6477, Val CER: 0.4155
#
# Epoch 5/100
# [5/100] Train Loss: 1.9698, Train CER: 0.5892 | Val Loss: 1.5945, Val CER: 0.3992
#
# Epoch 6/100
# [6/100] Train Loss: 1.9238, Train CER: 0.5621 | Val Loss: 1.5360, Val CER: 0.4050
#
# Epoch 7/100
# [7/100] Train Loss: 1.8856, Train CER: 0.5505 | Val Loss: 1.4781, Val CER: 0.3656
#
# Epoch 8/100
# [8/100] Train Loss: 1.8408, Train CER: 0.5276 | Val Loss: 1.4033, Val CER: 0.3380
#
# Epoch 9/100
# [9/100] Train Loss: 1.7984, Train CER: 0.5049 | Val Loss: 1.3796, Val CER: 0.3274
#
# Epoch 10/100
# [10/100] Train Loss: 1.7499, Train CER: 0.4906 | Val Loss: 1.2920, Val CER: 0.2986
#
# Epoch 11/100
# [11/100] Train Loss: 1.7161, Train CER: 0.4752 | Val Loss: 1.2709, Val CER: 0.2935
#
# Epoch 12/100
# [12/100] Train Loss: 1.6745, Train CER: 0.4582 | Val Loss: 1.1719, Val CER: 0.2682
#
# Epoch 13/100
# [13/100] Train Loss: 1.6101, Train CER: 0.4376 | Val Loss: 1.0748, Val CER: 0.2468
#
# Epoch 14/100
# [14/100] Train Loss: 1.5881, Train CER: 0.4338 | Val Loss: 1.0369, Val CER: 0.2297
#
# Epoch 15/100
# [15/100] Train Loss: 1.5249, Train CER: 0.4088 | Val Loss: 0.9810, Val CER: 0.2189
#
# Epoch 16/100
# [16/100] Train Loss: 1.4898, Train CER: 0.3981 | Val Loss: 0.9237, Val CER: 0.1975
#
# Epoch 17/100
# [17/100] Train Loss: 1.4488, Train CER: 0.3846 | Val Loss: 0.8946, Val CER: 0.1963
#
# Epoch 18/100
# [18/100] Train Loss: 1.4045, Train CER: 0.3729 | Val Loss: 0.8213, Val CER: 0.1813
#
# Epoch 19/100
# [19/100] Train Loss: 1.3815, Train CER: 0.3720 | Val Loss: 0.7924, Val CER: 0.1790
#
# Epoch 20/100
# [20/100] Train Loss: 1.3574, Train CER: 0.3657 | Val Loss: 0.7370, Val CER: 0.1537
#
# Epoch 21/100
# [21/100] Train Loss: 1.2991, Train CER: 0.3442 | Val Loss: 0.6959, Val CER: 0.1493
#
# Epoch 22/100
# [22/100] Train Loss: 1.2604, Train CER: 0.3411 | Val Loss: 0.6684, Val CER: 0.1412
#
# Epoch 23/100
# [23/100] Train Loss: 1.2269, Train CER: 0.3343 | Val Loss: 0.6038, Val CER: 0.1281
#
# Epoch 24/100
# [24/100] Train Loss: 1.2020, Train CER: 0.3277 | Val Loss: 0.5822, Val CER: 0.1264
#
# Epoch 25/100
# [25/100] Train Loss: 1.1431, Train CER: 0.3121 | Val Loss: 0.5614, Val CER: 0.1235
#
# Epoch 26/100
# [26/100] Train Loss: 1.1285, Train CER: 0.3092 | Val Loss: 0.5416, Val CER: 0.1166
#
# Epoch 27/100
# [27/100] Train Loss: 1.0976, Train CER: 0.3022 | Val Loss: 0.5074, Val CER: 0.1081
#
# Epoch 28/100
# [28/100] Train Loss: 1.0621, Train CER: 0.2914 | Val Loss: 0.4612, Val CER: 0.0991
#
# Epoch 29/100
# [29/100] Train Loss: 1.0448, Train CER: 0.2881 | Val Loss: 0.4331, Val CER: 0.0952
#
# Epoch 30/100
# [30/100] Train Loss: 1.0218, Train CER: 0.2850 | Val Loss: 0.4296, Val CER: 0.1012
#
# Epoch 31/100
# [31/100] Train Loss: 0.9980, Train CER: 0.2782 | Val Loss: 0.4119, Val CER: 0.0929
#
# Epoch 32/100
# [32/100] Train Loss: 0.9837, Train CER: 0.2780 | Val Loss: 0.4278, Val CER: 0.1062
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 33/100
# [33/100] Train Loss: 0.9548, Train CER: 0.2670 | Val Loss: 0.3902, Val CER: 0.0845
#
# Epoch 34/100
# [34/100] Train Loss: 0.9405, Train CER: 0.2668 | Val Loss: 0.3759, Val CER: 0.0819
#
# Epoch 35/100
# [35/100] Train Loss: 0.9132, Train CER: 0.2600 | Val Loss: 0.3335, Val CER: 0.0756
#
# Epoch 36/100
# [36/100] Train Loss: 0.8906, Train CER: 0.2557 | Val Loss: 0.3427, Val CER: 0.0761
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 37/100
# [37/100] Train Loss: 0.8954, Train CER: 0.2598 | Val Loss: 0.3676, Val CER: 0.0785
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 38/100
# [38/100] Train Loss: 0.8838, Train CER: 0.2559 | Val Loss: 0.3126, Val CER: 0.0681
#
# Epoch 39/100
# [39/100] Train Loss: 0.8503, Train CER: 0.2468 | Val Loss: 0.3295, Val CER: 0.0767
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 40/100
# [40/100] Train Loss: 0.8340, Train CER: 0.2421 | Val Loss: 0.3322, Val CER: 0.0693
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 41/100
# [41/100] Train Loss: 0.8149, Train CER: 0.2354 | Val Loss: 0.2971, Val CER: 0.0610
#
# Epoch 42/100
# [42/100] Train Loss: 0.8221, Train CER: 0.2436 | Val Loss: 0.3022, Val CER: 0.0669
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 43/100
# [43/100] Train Loss: 0.8085, Train CER: 0.2349 | Val Loss: 0.2834, Val CER: 0.0583
#
# Epoch 44/100
# [44/100] Train Loss: 0.7973, Train CER: 0.2341 | Val Loss: 0.2945, Val CER: 0.0633
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 45/100
# [45/100] Train Loss: 0.7717, Train CER: 0.2264 | Val Loss: 0.3176, Val CER: 0.0646
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 46/100
# [46/100] Train Loss: 0.7733, Train CER: 0.2269 | Val Loss: 0.3152, Val CER: 0.0643
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 47/100
# [47/100] Train Loss: 0.7690, Train CER: 0.2269 | Val Loss: 0.2845, Val CER: 0.0615
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 48/100
# [48/100] Train Loss: 0.7486, Train CER: 0.2246 | Val Loss: 0.2580, Val CER: 0.0536
#
# Epoch 49/100
# [49/100] Train Loss: 0.7420, Train CER: 0.2198 | Val Loss: 0.2525, Val CER: 0.0522
#
# Epoch 50/100
# [50/100] Train Loss: 0.7487, Train CER: 0.2257 | Val Loss: 0.2931, Val CER: 0.0619
# Validation loss did not improve. Early stop counter: 1/10
#
# Epoch 51/100
# [51/100] Train Loss: 0.7240, Train CER: 0.2148 | Val Loss: 0.2870, Val CER: 0.0615
# Validation loss did not improve. Early stop counter: 2/10
#
# Epoch 52/100
# [52/100] Train Loss: 0.7281, Train CER: 0.2175 | Val Loss: 0.2832, Val CER: 0.0605
# Validation loss did not improve. Early stop counter: 3/10
#
# Epoch 53/100
# [53/100] Train Loss: 0.7202, Train CER: 0.2157 | Val Loss: 0.2969, Val CER: 0.0640
# Validation loss did not improve. Early stop counter: 4/10
#
# Epoch 54/100
# [54/100] Train Loss: 0.7285, Train CER: 0.2204 | Val Loss: 0.2864, Val CER: 0.0589
# Validation loss did not improve. Early stop counter: 5/10
#
# Epoch 55/100
# [55/100] Train Loss: 0.7225, Train CER: 0.2179 | Val Loss: 0.2706, Val CER: 0.0582
# Validation loss did not improve. Early stop counter: 6/10
#
# Epoch 56/100
# [56/100] Train Loss: 0.7129, Train CER: 0.2126 | Val Loss: 0.2542, Val CER: 0.0529
# Validation loss did not improve. Early stop counter: 7/10
#
# Epoch 57/100
# [57/100] Train Loss: 0.7195, Train CER: 0.2202 | Val Loss: 0.2814, Val CER: 0.0573
# Validation loss did not improve. Early stop counter: 8/10
#
# Epoch 58/100
# [58/100] Train Loss: 0.7104, Train CER: 0.2182 | Val Loss: 0.2650, Val CER: 0.0499
# Validation loss did not improve. Early stop counter: 9/10
#
# Epoch 59/100
# [59/100] Train Loss: 0.7233, Train CER: 0.2185 | Val Loss: 0.2989, Val CER: 0.0615
# Validation loss did not improve. Early stop counter: 10/10
# Early stopping triggered.
#
# Training completed in 5h 49m.
#
# Results have been written to: training_results.csv
# swin_large_encoder — Test CER: 0.1829
#
# === Top 5 Worst Samples by CER ===
# 1) Image: test1330.png
#    CER: 13.0000
#    Predicted       : ingenaaaawaca
#    Ground Truth    : .
#
# 2) Image: test4934.png
#    CER: 11.0000
#    Predicted       : sanik-agung
#    Ground Truth    : .
#
# 3) Image: test2030.png
#    CER: 6.0000
#    Predicted       : nggnia
#    Ground Truth    : .
#
# 4) Image: test3029.png
#    CER: 5.0000
#    Predicted       : sanik
#    Ground Truth    : .
#
# 5) Image: test3142.png
#    CER: 4.0000
#    Predicted       : geng
#    Ground Truth    : i
#
# Logged swin_large_encoder: 0.1829
# Memory cleared for swin_large_encoder
